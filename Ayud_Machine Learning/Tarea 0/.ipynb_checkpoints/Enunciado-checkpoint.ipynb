# %% [markdown]
# <img src="http://www.exalumnos.usm.cl/wp-content/uploads/2015/06/Isotipo-Negro.gif" title="Title text" width="20%" height="20%" />
#
#
# <hr style="height:2px;border:none"/>
# <h1 align='center'> INF-393 Máquinas de Aprendizaje II-2018 </h1>
#
# <H3 align='center'> Tarea 0 - Introducción a Máquinas de Aprendizaje </H3>
# <hr style="height:2px;border:none"/>
#
# **Temas**
# * Introducción a librerías comunes de *Machine Learning*:
#     * Pandas
#     * Numpy
#     * Sklearn
#     * Matplotlib,..
# * Clasificación y regresión sobre texto.
# * Implementación a mano de regresión lineal.
# * Algoritmo Gradiente descendente
#
#
# ** Formalidades **
# * Equipos de trabajo de: 2 personas
# * Se debe preparar un (breve) Jupyter/IPython notebook que explique la actividad realizada y las conclusiones del trabajo
# * Fecha de entrega y discusión: 5 de Octubre.
# * Formato de entrega: envı́o de link Github al correo electrónico del ayudante (*<francisco.mena.13@sansano.usm.cl>*) , incluyendo al profesor en copia (*<jnancu@inf.utfsm.cl>*). Por favor especificar el siguiente asunto: [Tarea0-INF393-II-2018]
#
# <hr style="height:2px;border:none"/>
#
# La tarea se divide en secciones:
#
# [1.](#primero) Sentiment Analysis
# [2.](#segundo) Job Salary Prediction
# [3.](#tercero) Linear Regression by hand

# %% [markdown]
# <a id="primero"></a>
# ## 1. Sentiment Analysis [Sin evaluación]
# El análisis de emociones o sentimientos se refiere al proceso de extraer información acerca de la actitud
# que una persona (o grupo de ellas) manifiesta, en un determinado medio o formato digital, con respecto a un
# tópico o contexto de comunicación. Uno de los casos más estudiados corresponde a determinar la polaridad
# de un trozo de texto, es decir, clasificar una determinada evaluación escrita (*review*), en que una persona
# manifiesta una opinión, como *positiva*, *negativa* o *neutral*. Esto también ha sido extendido a otros medios, como lo es analizar la polaridad de textos en redes sociales.
#
# <img src="https://cdn.urgente24.com/sites/default/files/notas/2018/01/18/twitter.png" title="Title text" width="20%" height="20%" />
#
#
# La conocida red social Twitter tiene una gran cantidad de usuarios, por lo que la información se genera a
# cada segundo, donde el análisis de texto se ha aplicado fuertemente a estos medios sociales. La dificultad de
# este problema radica en el carácter altamente ambiguo e informal del lenguaje que utilizan naturalmente las
# personas ası́ como el manejo de negaciones, sarcasmo y abreviaciones en una frase.
#
#
# Los datos pueden ser descargados ejecutando el siguiente código en sistema Unix:
# ```
# wget -o train_data.csv http://www.inf.utfsm.cl/~jnancu/stanford-subset/polarity.train
# wget -o test_data.csv http://www.inf.utfsm.cl/~jnancu/stanford-subset/polarity.dev
# ```
#
# Para construir un clasificador que determine automáticamente la polaridad de un trozo de texto, vamos a necesitar representar los textos $\{d_i\}_{i=1}^n$ disponibles como vectores de caracterı́sticas (features). Para aumentar la eficacia de las caracterı́sticas extraı́das es conveniente ejecutar algunas técnicas de pre-procesamiento básicas como: pasar todo el texto a minúsculas (lower-casing), eliminar signos de puntuación
# y eliminar palabras sin significado como artı́culos, pronombres y preposiciones (*stop word removal*). Otra
# técnica que suele ser útil para obtener buenas caracterı́sticas (*features*) es la lematización, es decir, la
# reducción de todas las palabras a su tronco léxico base. Una técnica similar y más utilizada en la práctica es el stemming. Varias de éstas están implementadas en la libreria nltk [13] para python.
#
#
# > a) Construya un dataframe con los datos a analizar. Determine cuántas clases existen, cuántos registros
# por clase y describa el dataset.
# ``` python
# import pandas as pd
# ftr = open("train_data.csv", "r")
# fts = open("test_data.csv", "r")
# rows = [line.split(" ",1) for line in ftr.readlines()]
# df_train = pd.DataFrame(rows, columns=['Sentiment','Text'])
# df_train['Sentiment'] = pd.to_numeric(df_train['Sentiment'])
# rows = [line.split(" ",1) for line in fts.readlines()]
# df_test = pd.DataFrame(rows, columns=['Sentiment','Text'])
# df_test['Sentiment'] = pd.to_numeric(df_test['Sentiment'])
# df_train.shape
# ```
#
# > b) Construya un conjunto de validación (también conocido como *hold out validation*), a través de una máscara aleatoria, para verificar los resultados de los algoritmos.
# ``` python
# import numpy as np
# msk = np.random.rand(len(df_train)) < 0.8
# df_new_train = df_train[msk]
# df_val = df_train[~msk]
# ```
#
# > c) Implemente y explique un pre-procesamiento para los tweets para dejarlos en un formato estándarizado
# en el cual se podrán trabajar.
# ```python
# import re, time
# from nltk.corpus import stopwords
# from nltk import WordNetLemmatizer, word_tokenize
# from nltk.stem.porter import PorterStemmer
# def word_extractor(text):
#     wordlemmatizer = WordNetLemmatizer()
#     wordstemmer = PorterStemmer()
#     commonwords = stopwords.words('english')
#     text = re.sub(r'([a-z])\1+', r'\1\1',text)#substitute multiple letter by two
#     words = ""
#     wordtokens = [ wordstemmer.stem(word.lower())for word in word_tokenize(text.decode('utf-8', 'ignore')) ]
#     for word in wordtokens:
#         if word not in commonwords:
#             words+=" "+word
#     return words
# word_extractor("I love to eat cake")
# word_extractor("I love eating cake")
# word_extractor("I loved eating the cake")
# word_extractor("I do not love eating cake")
# word_extractor("I don't love eating cake")
# ...
# wordlemmatizer.lemmatize(word.lower()) #can use this
# ```
#
# > d) Utilizando la función *CountVectorizer* de la librerı́a sklearn genere una representación vectorial del texto de entrenamiento y del conjunto que usaremos para realizar la validación. Esta función consiste en contar cuántas veces aparecen ciertos términos/palabras en el texto a través de un vocabulario que construiremos mediante la unión de todas las palabras que observemos en los textos que tenemos a disposición. Explore el vocabulario utilizado y determine cuáles son las palabras más frecuentes en el conjunto de entrenamiento y pruebas.
# ``` python
# import numpy as np
# from sklearn.feature_extraction.text import CountVectorizer
# texts_train = [word_extractor(text) for text in df_new_train.Text]
# texts_val = [word_extractor(text) for text in df_val.Text]
# texts_test = [word_extractor(text) for text in df_test.Text]
# vectorizer = CountVectorizer(ngram_range=(1, 1), binary='False')
# vectorizer.fit(np.asarray(texts_train))
# features_train = vectorizer.transform(texts_train)
# features_val = vectorizer.transform(texts_val)
# features_test = vectorizer.transform(texts_test)
# labels_train = np.asarray((df_new_train.Sentiment.astype(float)+1)/2.0)
# labels_val = np.asarray((df_val.Sentiment.astype(float)+1)/2.0)
# labels_test = np.asarray((df_test.Sentiment.astype(float)+1)/2.0)
# vocab = vectorizer.get_feature_names()
# dist=list(np.array(features_train.sum(axis=0)).reshape(-1,))
# for tag, count in zip(vocab, dist):
#     print count, tag
# ```
#
# > e) Construya una función que entrene/ajuste un modelo de Regresión Logı́stica y mida el error de predicción obtenido sobre los datos de entrenamiento y validación. Experimente con variar la representación o preprocesamiento, por ejemplo el efecto de filtrar *stopwords* y de eliminar este paso de
# pre-procesamiento tı́pico. Determine además, qué representación obtiene un mejor resultado: si aquella obtenida vı́a lematización o aquella obtenida vı́a *stemming*. Seleccione el mejor modelo y mida sobre *test*. Comente
# ``` python
# from sklearn.linear_model import LogisticRegression
# def do_LOGIT(x,y,xv,yv):
#     model = LogisticRegression()
#     model = model.fit(x, y)
#     print("Accuracy under training: ",model.score(x,y))
#     print("Accuracy under validation: ",model.score(xv,yv))
#     return model
# log_model = do_LOGIT(features_train,labels_train,features_val,labels_val)
# ```
#
# > f) Finalmente, tome un subconjunto aleatorio de los textos de prueba y analice las predicciones del modelo (explore las predicciones, ası́ como las probabilidades que el clasificador asigna a cada clase)

# %%
https://github.com/FMena14/MachineLearning2/blob/master/Parte2.ipynb

# %%
import pandas as pd
ftr = open("train_data.csv", "r")
fts = open("test_data.csv", "r")
rows = [line.split(" ",1) for line in ftr.readlines()]
df_train = pd.DataFrame(rows, columns=['Sentiment','Text'])
df_train['Sentiment'] = pd.to_numeric(df_train['Sentiment'])
rows = [line.split(" ",1) for line in fts.readlines()]
df_test = pd.DataFrame(rows, columns=['Sentiment','Text'])
df_test['Sentiment'] = pd.to_numeric(df_test['Sentiment'])
df_train.shape
# Out:
# (3554, 2)

# %%
import numpy as np
msk = np.random.rand(len(df_train)) < 0.8
df_new_train = df_train[msk]
df_val = df_train[~msk]

# %%
import re, time
from nltk.corpus import stopwords
from nltk import WordNetLemmatizer, word_tokenize
from nltk.stem.porter import PorterStemmer
def word_extractor(text):
    wordlemmatizer = WordNetLemmatizer()
    wordstemmer = PorterStemmer()
    commonwords = stopwords.words('english')
    text = re.sub(r'([a-z])\1+', r'\1\1',text)#substitute multiple letter by two
    words = ""
    wordtokens = [ wordstemmer.stem(word.lower())for word in word_tokenize(text.decode('utf-8', 'ignore')) ]
    for word in wordtokens:
        if word not in commonwords:
            words+=" "+word
    return words

def word_extractor2(text):
    wordlemmatizer = WordNetLemmatizer()
    wordstemmer = PorterStemmer()
    commonwords = stopwords.words('english')
    text = re.sub(r'([a-z])\1+', r'\1\1',text)#substitute multiple letter by two
    words = ""
    wordtokens = [ wordlemmatizer.lemmatize(word.lower())for word in word_tokenize(text.decode('utf-8', 'ignore')) ]
    for word in wordtokens:
        if word not in commonwords:
            words+=" "+word
    return words
word_extractor("I love to eat cake")
word_extractor("I love eating cake")
word_extractor("I loved eating the cake")
word_extractor("I do not love eating cake")
word_extractor2("I don't love eating cake")
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# <ipython-input-15-3535faebfbce> in <module>()
#      30 word_extractor("I loved eating the cake")
#      31 word_extractor("I do not love eating cake")
# ---> 32 word_extractor2("I don't love eating cake")
#      33
#
# <ipython-input-15-3535faebfbce> in word_extractor2(text)
#      21     text = re.sub(r'([a-z])\1+', r'\1\1',text)#substitute multiple letter by two
#      22     words = ""
# ---> 23     wordtokens = [ wordlemmatizer.lemmatize(word.lower())for word in word_tokenize(text.decode('utf-8', 'ignore')) ]
#      24     for word in wordtokens:
#      25         if word not in commonwords:
#
# /home/fmena/anaconda2/lib/python2.7/site-packages/nltk/stem/wordnet.pyc in lemmatize(self, word, pos)
#      38
#      39     def lemmatize(self, word, pos=NOUN):
# ---> 40         lemmas = wordnet._morphy(word, pos)
#      41         return min(lemmas, key=len) if lemmas else word
#      42
#
# /home/fmena/anaconda2/lib/python2.7/site-packages/nltk/corpus/util.pyc in __getattr__(self, attr)
#     114             raise AttributeError("LazyCorpusLoader object has no attribute '__bases__'")
#     115
# --> 116         self.__load()
#     117         # This looks circular, but its not, since __load() changes our
#     118         # __class__ to something new:
#
# /home/fmena/anaconda2/lib/python2.7/site-packages/nltk/corpus/util.pyc in __load(self)
#      79             except LookupError as e:
#      80                 try: root = nltk.data.find('{}/{}'.format(self.subdir, zip_name))
# ---> 81                 except LookupError: raise e
#      82
#      83         # Load the corpus.
#
# LookupError:
# **********************************************************************
#   Resource wordnet not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('wordnet')
#
#   Searched in:
#     - '/home/fmena/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/local/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/local/lib/nltk_data'
#     - '/home/fmena/anaconda2/nltk_data'
#     - '/home/fmena/anaconda2/share/nltk_data'
#     - '/home/fmena/anaconda2/lib/nltk_data'
# **********************************************************************

# %%
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
texts_train = [word_extractor(text) for text in df_new_train.Text]
texts_val = [word_extractor(text) for text in df_val.Text]
texts_test = [word_extractor(text) for text in df_test.Text]
vectorizer = CountVectorizer(ngram_range=(1, 1), binary='False')
vectorizer.fit(np.asarray(texts_train))
features_train = vectorizer.transform(texts_train)
features_val = vectorizer.transform(texts_val)
features_test = vectorizer.transform(texts_test)
labels_train = np.asarray((df_new_train.Sentiment.astype(float)+1)/2.0)
labels_val = np.asarray((df_val.Sentiment.astype(float)+1)/2.0)
labels_test = np.asarray((df_test.Sentiment.astype(float)+1)/2.0)
vocab = vectorizer.get_feature_names()
dist=list(np.array(features_train.sum(axis=0)).reshape(-1,))
for tag, count in zip(vocab, dist):
    print count, tag
# Out:
# 4 10
# 3 100
# 2 101
# 1 105
# 2 10th
# 2 11
# 1 110
# 2 13
# 1 13th
# 2 15
# 1 16
# 1 163
# 2 170
# 1 18th
# 3 19
# 2 1915
# 1 1938
# 1 1940
# 2 1950
# 1 1955
# 1 1958
# 1 1959
# 2 1960
# 1 1967
# 1 1972
# 2 1975
# 1 1979
# 2 1980
# 1 1991
# 1 1992
# 2 1995
# 3 19th
# 2 20
# 1 2000
# 4 2002
# 4 20th
# 1 21st
# 1 24
# 3 25
# 3 30
# 1 300
# 2 3000
# 1 37
# 1 3d
# 4 40
# 1 400
# 1 401
# 1 451
# 1 49
# 3 4ever
# 2 50
# 1 51
# 1 53
# 1 60
# 1 60s
# 1 65
# 1 65th
# 3 70
# 1 77
# 1 79
# 5 80
# 1 800
# 1 84
# 2 85
# 1 88
# 1 8th
# 13 90
# 1 94
# 1 95
# 1 96
# 1 97
# 1 99
# 1 aaliyah
# 1 abandon
# 1 abbass
# 1 abbrevi
# 1 abc
# 2 abel
# 1 abhorr
# 1 abid
# 9 abil
# 5 abl
# 2 abli
# 1 aboul
# 11 abov
# 3 above
# 1 abraham
# 1 abram
# 1 abras
# 1 abroad
# 6 absolut
# 8 absorb
# 1 absorpt
# 5 abstract
# 5 absurd
# 3 absurdist
# 1 aburrido
# 2 abus
# 1 abysm
# 1 academ
# 2 academi
# 6 accent
# 1 accentu
# 3 accept
# 6 access
# 1 accid
# 2 accident
# 3 accompani
# 6 accomplish
# 1 accord
# 4 account
# 1 accumul
# 2 accur
# 1 accus
# 1 acerta
# 1 ach
# 10 achiev
# 1 achil
# 4 achingli
# 1 acid
# 2 acknowledg
# 1 acolyt
# 1 acquir
# 1 acr
# 1 acrid
# 8 across
# 59 act
# 1 acting
# 46 action
# 2 activ
# 1 activist
# 39 actor
# 1 actorli
# 12 actress
# 1 actuacion
# 16 actual
# 4 ad
# 2 adag
# 2 adam
# 17 adapt
# 13 add
# 5 addit
# 1 address
# 1 adicion
# 1 adject
# 1 administr
# 12 admir
# 1 admiss
# 2 admittedli
# 1 adobo
# 6 adolesc
# 2 ador
# 2 adorn
# 1 adren
# 1 adrenalin
# 1 adroit
# 1 adroitli
# 9 adult
# 3 advanc
# 14 adventur
# 1 advers
# 1 advertis
# 1 advic
# 1 advis
# 1 aerial
# 3 aesthet
# 2 affabl
# 6 affair
# 10 affect
# 1 affection
# 1 affin
# 7 affirm
# 2 affleck
# 1 affluenc
# 1 afghan
# 1 afghani
# 4 afloat
# 1 africa
# 1 african
# 7 after
# 3 afternoon
# 2 afterschool
# 1 aftertast
# 11 ag
# 1 again
# 1 agap
# 17 age
# 3 agenda
# 3 agent
# 1 aggrand
# 1 aggrav
# 3 aggress
# 10 ago
# 1 agre
# 3 ah
# 1 ahem
# 1 ahh
# 1 ahola
# 2 ai
# 3 aid
# 1 aiello
# 8 aim
# 1 aimless
# 3 aimlessli
# 1 ain
# 7 air
# 1 airborn
# 1 airhead
# 2 airless
# 2 al
# 2 ala
# 2 alabama
# 1 alacr
# 1 alain
# 2 alan
# 1 alarm
# 1 alarmingli
# 1 albeit
# 1 album
# 1 alcatraz
# 2 alert
# 1 alexandr
# 2 alia
# 10 alien
# 1 alik
# 5 aliv
# 5 all
# 2 allegedli
# 1 allegori
# 10 allen
# 1 allergi
# 1 alli
# 9 allow
# 1 alma
# 2 almodovar
# 33 almost
# 1 aloft
# 5 alon
# 11 along
# 1 alongsid
# 1 aloof
# 11 alreadi
# 42 also
# 1 alt
# 8 altern
# 18 although
# 1 alvo
# 20 alway
# 3 amalgam
# 1 amari
# 1 amaro
# 5 amateurish
# 9 amaz
# 2 amazingli
# 1 ambienc
# 3 ambigu
# 4 ambit
# 8 ambiti
# 2 ambival
# 1 ambros
# 8 america
# 27 american
# 1 americana
# 2 ami
# 2 amiabl
# 1 amid
# 1 amini
# 1 amli
# 7 among
# 7 amount
# 1 amped
# 1 ampl
# 19 amus
# 1 ana
# 1 anachronist
# 1 anakin
# 1 analges
# 1 analysi
# 1 analyt
# 1 anarch
# 2 anarchist
# 1 anchor
# 1 ancient
# 15 and
# 1 andersson
# 1 andi
# 1 andrei
# 1 andrew
# 2 anem
# 1 anew
# 6 angel
# 1 angeliqu
# 3 angl
# 4 angri
# 2 angst
# 1 anguish
# 54 ani
# 23 anim
# 2 ann
# 2 anne
# 1 annie
# 1 anniversari
# 9 annoy
# 1 annoyingli
# 1 anomi
# 1 anonym
# 37 anoth
# 8 answer
# 1 ant
# 2 anthoni
# 1 anthropolog
# 6 anti
# 1 antic
# 1 anticip
# 1 antisept
# 1 antonia
# 1 antsi
# 2 antwon
# 2 anybodi
# 2 anymor
# 31 anyon
# 21 anyth
# 5 anyway
# 3 anywher
# 1 ao
# 7 apart
# 2 ape
# 1 apollo
# 2 appal
# 6 appar
# 18 appeal
# 15 appear
# 1 appeas
# 1 appet
# 1 appl
# 2 applaud
# 2 appli
# 1 appoint
# 4 appreci
# 9 approach
# 6 appropri
# 2 apt
# 1 apuesta
# 1 aquat
# 2 ararat
# 1 arbitrari
# 1 arcan
# 1 arcana
# 1 arch
# 1 archibald
# 3 architectur
# 2 archiv
# 1 ardent
# 2 are
# 3 area
# 1 argentin
# 2 argento
# 2 argu
# 1 argument
# 1 argumentao
# 1 aris
# 3 aristocrat
# 1 arithmet
# 1 ark
# 1 arkin
# 1 arliss
# 2 arm
# 1 armenia
# 1 armenian
# 3 arnold
# 12 around
# 1 arrang
# 1 array
# 5 arrest
# 2 arriv
# 1 arrog
# 32 art
# 1 artefact
# 1 arti
# 3 articul
# 3 artific
# 2 artifici
# 16 artist
# 1 artistri
# 3 artsi
# 1 as
# 1 asay
# 1 ascens
# 1 ascertain
# 1 ash
# 5 asian
# 7 asid
# 10 ask
# 1 asleep
# 4 aspect
# 1 asphalt
# 2 aspir
# 1 ass
# 3 assassin
# 1 assault
# 1 assaya
# 1 assert
# 1 assess
# 3 asset
# 1 assign
# 1 assimil
# 3 associ
# 3 assum
# 3 assur
# 1 assuredli
# 4 astonish
# 1 astonishingli
# 1 astound
# 2 astray
# 1 astut
# 2 asylum
# 1 at
# 1 atavist
# 2 athlet
# 1 athletic
# 8 atmospher
# 1 aton
# 1 atop
# 3 atroci
# 2 attach
# 1 attack
# 3 attal
# 19 attempt
# 10 attent
# 3 attitud
# 8 attract
# 1 attun
# 2 audac
# 1 audiard
# 60 audienc
# 1 audience
# 1 audrey
# 1 augment
# 1 august
# 2 auschwitz
# 1 aussi
# 2 auster
# 1 austin
# 2 australia
# 1 austrian
# 2 auteur
# 5 authent
# 5 author
# 3 auto
# 1 autom
# 3 automat
# 1 avalanch
# 1 avant
# 4 avari
# 1 aveng
# 12 averag
# 1 avers
# 1 avert
# 12 avoid
# 12 aw
# 1 awak
# 3 awar
# 5 award
# 25 away
# 5 awe
# 4 awesom
# 7 awkward
# 2 awkwardli
# 1 ayala
# 1 baader
# 1 babbitt
# 1 babe
# 1 babi
# 1 baboon
# 1 baby
# 1 babysitt
# 1 baca
# 37 back
# 2 backdrop
# 5 background
# 1 backseat
# 2 bacon
# 66 bad
# 1 badder
# 1 badg
# 6 badli
# 2 baffl
# 5 bag
# 1 bagatel
# 1 baggag
# 1 baio
# 1 bait
# 1 bak
# 1 bal
# 8 balanc
# 1 bale
# 1 ball
# 1 ballast
# 1 ballerina
# 2 ballet
# 2 ballist
# 1 ballistic
# 1 balloon
# 2 ballot
# 1 balm
# 1 balto
# 1 bam
# 2 banal
# 7 band
# 4 bang
# 1 banger
# 2 bar
# 1 baran
# 1 barbar
# 1 barbara
# 1 barbera
# 1 barbershop
# 1 bard
# 11 bare
# 1 bargain
# 1 barker
# 1 barlow
# 2 barney
# 1 baroqu
# 1 barrag
# 5 barri
# 2 barrier
# 1 barrymor
# 3 bartlebi
# 1 bas
# 9 base
# 1 basebal
# 4 basi
# 7 basic
# 1 bass
# 2 bastard
# 1 bastion
# 3 bath
# 1 batho
# 1 bathroom
# 6 battl
# 2 battlefield
# 1 bawdi
# 1 be
# 2 beach
# 1 beachcomb
# 2 beacon
# 2 bean
# 4 bear
# 2 bearabl
# 11 beat
# 1 beaten
# 1 beatnik
# 1 beatric
# 1 beaus
# 32 beauti
# 1 becam
# 36 becaus
# 1 beck
# 39 becom
# 1 bedouin
# 1 bedsid
# 1 bedtim
# 1 been
# 2 beer
# 1 befit
# 29 befor
# 3 befuddl
# 2 beg
# 2 began
# 12 begin
# 2 beguil
# 1 begun
# 1 behan
# 1 behaving
# 1 behavior
# 1 behaviour
# 8 behind
# 3 beij
# 1 belat
# 1 belgium
# 3 belief
# 18 believ
# 1 belo
# 3 belong
# 1 belov
# 2 belt
# 1 belushi
# 3 ben
# 2 benchmark
# 3 beneath
# 3 benefit
# 1 benign
# 4 benigni
# 1 benjamin
# 1 benshan
# 1 beresford
# 1 bergmanesqu
# 1 berkley
# 1 berlin
# 1 bernal
# 3 besid
# 65 best
# 1 bet
# 1 betray
# 1 bettani
# 31 better
# 2 betti
# 1 bewild
# 1 bewilderingli
# 1 bewitch
# 14 beyond
# 1 bi
# 1 bias
# 2 bibi
# 1 bicycl
# 1 bidder
# 2 bielinski
# 1 bien
# 46 big
# 1 bigelow
# 2 bigger
# 3 biggest
# 1 bike
# 1 bile
# 3 bill
# 1 bind
# 1 bink
# 4 binoch
# 1 bio
# 4 biopic
# 1 bird
# 1 birkenau
# 3 birot
# 1 birth
# 3 birthday
# 1 bisexu
# 1 bishop
# 1 bisset
# 20 bit
# 5 bite
# 2 bitten
# 3 bitter
# 4 bittersweet
# 2 biz
# 3 bizarr
# 9 black
# 3 blade
# 2 blair
# 2 blame
# 10 bland
# 2 blandli
# 2 blank
# 1 blanket
# 1 blare
# 1 blasphem
# 2 blast
# 1 blatant
# 1 blaze
# 2 bleak
# 1 bled
# 14 blend
# 1 blender
# 3 bless
# 1 bleu
# 1 blimey
# 1 blimp
# 1 blind
# 2 blisteringli
# 1 blob
# 2 blockbust
# 1 blond
# 5 blood
# 2 bloodi
# 2 bloodsh
# 1 bloodstream
# 1 bloodsuck
# 3 blow
# 1 blown
# 1 blowout
# 1 blu
# 4 blue
# 1 blueprint
# 1 bluescreen
# 1 bluff
# 1 blush
# 1 bmw
# 2 bmx
# 2 board
# 1 boarder
# 1 boardwalk
# 6 boast
# 2 boat
# 4 bodi
# 1 bodice
# 1 bodili
# 4 bog
# 1 bogdanich
# 1 boggl
# 1 bogu
# 1 boil
# 1 boister
# 3 bold
# 1 bolder
# 1 boldli
# 1 bolero
# 4 bollywood
# 1 bolster
# 3 bomb
# 1 bombast
# 1 bombay
# 1 bona
# 6 bond
# 1 bondish
# 3 bone
# 1 bonehead
# 1 bonu
# 2 boob
# 21 book
# 5 boom
# 1 boomer
# 1 boot
# 1 booti
# 2 boozi
# 8 border
# 1 borderlin
# 29 bore
# 1 boredom
# 1 born
# 2 borrow
# 1 botch
# 6 bother
# 1 bothersom
# 2 bottom
# 1 bought
# 3 bounci
# 3 bound
# 5 bourn
# 2 bout
# 3 bow
# 1 bowel
# 1 bowl
# 4 box
# 18 boy
# 1 boyd
# 1 brace
# 1 bradi
# 6 brain
# 3 brainless
# 1 branagh
# 1 brand
# 1 brash
# 2 brass
# 1 bratt
# 2 bratti
# 1 bravado
# 4 brave
# 1 braveheart
# 2 bravo
# 1 bravura
# 1 brawn
# 1 brawni
# 1 brazen
# 1 brazenli
# 14 break
# 3 breakdown
# 2 breakthrough
# 8 breath
# 1 breathless
# 4 breathtak
# 1 breathtakingli
# 4 breezi
# 1 breitbart
# 3 brendan
# 1 brian
# 1 bride
# 2 bridg
# 1 bridget
# 1 brief
# 1 briefli
# 5 bright
# 1 brightli
# 1 brilhantismo
# 1 brillianc
# 11 brilliant
# 8 brilliantli
# 2 brim
# 23 bring
# 1 brink
# 2 brio
# 1 brisk
# 1 brit
# 5 british
# 2 britney
# 4 broad
# 2 broadway
# 1 broder
# 2 brogu
# 1 broil
# 2 broke
# 3 broken
# 1 bromid
# 3 brooklyn
# 1 broomfield
# 1 brosnan
# 9 brother
# 1 brothers
# 4 brought
# 1 brown
# 3 bruce
# 1 bruckheim
# 1 brunt
# 2 brush
# 7 brutal
# 1 bryan
# 2 bu
# 3 bubbl
# 5 buddi
# 1 buddy
# 9 budget
# 1 bueller
# 2 buff
# 1 buffet
# 1 buffoon
# 1 buggi
# 1 bui
# 9 build
# 4 built
# 1 bull
# 2 bullet
# 1 bullfight
# 4 bullock
# 1 bullwinkl
# 1 bump
# 1 bumper
# 4 bunch
# 1 bundi
# 2 buoyant
# 1 burdett
# 1 burger
# 3 buri
# 1 burk
# 4 burn
# 1 burnt
# 1 burr
# 3 burst
# 1 burstein
# 1 buscemi
# 1 bush
# 7 busi
# 3 bust
# 1 bustl
# 1 butler
# 1 butt
# 1 butterfing
# 1 butterworth
# 2 button
# 2 buuel
# 6 buy
# 1 buzz
# 3 by
# 1 byatt
# 1 bygon
# 1 byler
# 1 bypass
# 1 byron
# 33 ca
# 1 cabl
# 1 cable
# 1 cackl
# 1 cacophoni
# 1 cada
# 1 caddyshack
# 1 caesar
# 1 caf
# 1 cafe
# 1 caffein
# 5 cage
# 5 cain
# 2 cal
# 1 calam
# 7 calcul
# 2 calib
# 2 calibr
# 1 california
# 21 call
# 3 callar
# 1 callow
# 1 calvin
# 1 camaraderi
# 2 came
# 2 cameo
# 14 camera
# 1 cameron
# 1 camouflag
# 7 camp
# 1 campfir
# 1 campion
# 1 campu
# 2 canada
# 1 canadian
# 1 cancer
# 1 candi
# 1 candidli
# 1 candl
# 1 candy
# 1 cann
# 3 canni
# 1 canning
# 1 canon
# 1 cantet
# 3 capabl
# 2 capac
# 5 caper
# 1 capit
# 1 caprici
# 1 capsul
# 1 captain
# 4 captiv
# 1 captivatingli
# 1 captor
# 18 captur
# 6 car
# 2 card
# 1 cardboard
# 1 cardellini
# 1 cardoso
# 23 care
# 1 careen
# 11 career
# 1 caretak
# 1 careworn
# 2 caricatur
# 1 carl
# 1 carlin
# 1 carmen
# 1 carnag
# 1 carnahan
# 2 carol
# 1 carpent
# 6 carri
# 1 carter
# 10 cartoon
# 2 cartoonish
# 3 caruso
# 1 carv
# 2 carvey
# 12 case
# 1 casey
# 2 cash
# 1 casi
# 55 cast
# 3 castro
# 2 casual
# 3 cat
# 1 catalog
# 1 catalyt
# 6 catch
# 1 catchi
# 3 categori
# 1 catharsi
# 2 cathol
# 1 catholic
# 1 caton
# 1 cattaneo
# 2 caught
# 2 caus
# 5 cautionari
# 1 cavort
# 1 cedar
# 1 celeb
# 9 celebr
# 2 celebratori
# 1 celibaci
# 1 cell
# 1 celluloid
# 1 censur
# 2 cent
# 6 center
# 1 centr
# 5 central
# 9 centuri
# 1 cerebr
# 1 ceremoni
# 7 certain
# 15 certainli
# 3 cgi
# 3 chabrol
# 1 chaiken
# 1 chain
# 1 chainsaw
# 6 challeng
# 1 challenge
# 1 chamber
# 2 championship
# 7 chan
# 6 chanc
# 20 chang
# 6 channel
# 2 chao
# 4 chaotic
# 1 chapter
# 123 charact
# 7 character
# 1 characteris
# 3 characterist
# 3 charg
# 5 charisma
# 2 charismat
# 1 charit
# 1 charl
# 1 charleston
# 4 charli
# 33 charm
# 1 charmingli
# 1 charmless
# 1 chart
# 5 chase
# 2 chateau
# 1 chatter
# 10 cheap
# 1 cheapen
# 3 cheat
# 1 check
# 4 cheek
# 1 cheeki
# 2 cheer
# 1 chees
# 5 cheesi
# 1 chekhov
# 2 chelsea
# 3 chemistri
# 2 cherish
# 1 cherri
# 4 chest
# 1 chevi
# 4 chew
# 2 chicago
# 1 chicaneri
# 3 chick
# 1 chief
# 2 chiefli
# 5 child
# 4 childhood
# 2 childish
# 16 children
# 9 chill
# 3 chilli
# 1 chillingli
# 1 chimney
# 1 chimpanze
# 2 china
# 3 chines
# 4 cho
# 1 chocol
# 6 choic
# 1 choke
# 1 chomp
# 1 choos
# 4 choppi
# 1 chopsocki
# 1 choquart
# 1 chore
# 2 choreograph
# 2 choreographi
# 1 chosen
# 2 chouraqui
# 2 chri
# 3 christian
# 2 christma
# 1 christoph
# 3 chronicl
# 2 chteau
# 1 chuck
# 5 chuckl
# 1 chump
# 1 churn
# 2 cia
# 1 cigarett
# 2 cinderella
# 1 cineast
# 22 cinema
# 16 cinemat
# 2 cinematograph
# 7 cinematographi
# 1 cinephil
# 2 cinta
# 1 cipher
# 1 circa
# 2 circl
# 1 circu
# 2 circumst
# 1 circumstanti
# 6 citi
# 1 civic
# 1 civil
# 1 clad
# 1 clam
# 2 clamor
# 1 clan
# 1 clanci
# 1 clare
# 3 clariti
# 1 clarke
# 4 clash
# 10 class
# 1 classi
# 14 classic
# 1 claud
# 3 claus
# 3 claustrophob
# 1 clean
# 1 cleans
# 13 clear
# 7 clearli
# 16 clever
# 3 cleverli
# 27 clich
# 3 clichd
# 3 cliche
# 1 client
# 1 cliff
# 1 cliffhang
# 2 climat
# 2 climax
# 1 climb
# 4 clinic
# 1 clip
# 1 clive
# 2 cloak
# 1 clobber
# 1 clock
# 1 clockstopp
# 3 clone
# 3 clooney
# 16 close
# 1 closed
# 5 closer
# 1 clot
# 1 clout
# 1 clown
# 3 cloy
# 1 cloyingli
# 4 club
# 2 clue
# 2 clueless
# 8 clumsi
# 1 clumsili
# 1 clunk
# 2 clunki
# 1 clutch
# 12 co
# 1 coal
# 1 coars
# 1 coast
# 1 coaster
# 2 cobbl
# 1 cockett
# 1 cockney
# 3 code
# 1 cogent
# 4 coher
# 3 cohes
# 2 coincid
# 1 coke
# 16 cold
# 1 coldli
# 1 collabor
# 2 collaps
# 2 collater
# 1 colleagu
# 7 collect
# 6 colleg
# 1 college
# 1 colli
# 1 collid
# 3 collis
# 1 colonialist
# 19 color
# 1 colosseum
# 1 colour
# 1 columbin
# 1 columbu
# 3 com
# 1 coma
# 1 comatos
# 1 combat
# 9 combin
# 1 combust
# 56 come
# 5 comed
# 114 comedi
# 2 comedian
# 3 comedy
# 1 comfi
# 6 comfort
# 23 comic
# 10 coming
# 3 command
# 2 comment
# 2 commentari
# 5 commerci
# 5 commit
# 1 commod
# 3 common
# 1 commonplac
# 7 commun
# 1 como
# 4 compani
# 1 companion
# 3 compar
# 3 comparison
# 2 compass
# 22 compel
# 1 compendium
# 1 compenetrado
# 2 compet
# 1 competit
# 1 compil
# 1 complain
# 20 complet
# 13 complex
# 4 complic
# 1 compliment
# 1 compon
# 4 compos
# 1 composit
# 1 comprehens
# 1 compris
# 2 compromis
# 1 comprueba
# 3 compuls
# 6 comput
# 1 computer
# 4 con
# 1 conceal
# 1 conceit
# 3 conceiv
# 2 concentr
# 14 concept
# 2 conceptu
# 8 concern
# 2 concert
# 1 conclud
# 3 conclus
# 3 concoct
# 1 condens
# 1 condescend
# 1 condescens
# 2 condit
# 5 conduct
# 1 condundrum
# 1 cone
# 2 confess
# 2 confession
# 2 confid
# 1 confin
# 1 conflagr
# 5 conflict
# 1 confluenc
# 2 confront
# 6 confus
# 1 congratul
# 4 conjur
# 1 conmovedora
# 12 connect
# 2 connoisseur
# 1 conquer
# 1 conrad
# 5 consci
# 1 conscienti
# 1 consciou
# 3 conscious
# 1 consciousness
# 1 consequ
# 8 consid
# 6 consider
# 1 consiglier
# 1 consign
# 4 consist
# 3 conspicu
# 2 conspiraci
# 1 conspiratori
# 4 constant
# 6 constantli
# 13 construct
# 2 consum
# 1 consumm
# 1 contact
# 1 contagi
# 5 contain
# 2 contempl
# 8 contemporari
# 1 contemptu
# 2 contend
# 2 content
# 1 contentedli
# 2 contest
# 5 context
# 1 contin
# 6 continu
# 1 contort
# 1 contradict
# 2 contradictori
# 1 contrari
# 3 contrast
# 2 contribut
# 14 contriv
# 8 control
# 1 controversi
# 1 contruct
# 1 convenc
# 1 conveni
# 10 convent
# 5 convers
# 4 convert
# 7 convey
# 2 convict
# 13 convinc
# 3 convolut
# 1 cook
# 1 cooker
# 13 cool
# 1 coolidg
# 1 cooper
# 9 cop
# 3 cope
# 1 copi
# 1 copmovieland
# 1 copout
# 3 coppola
# 3 cor
# 2 core
# 3 corner
# 3 corni
# 1 corpor
# 3 corps
# 2 correct
# 1 corrupt
# 4 cost
# 2 costli
# 1 costner
# 5 costum
# 1 cotswold
# 63 could
# 1 coulda
# 5 count
# 3 counterpart
# 1 counti
# 2 countless
# 4 countri
# 7 coupl
# 2 courag
# 10 cours
# 1 court
# 1 courtroom
# 1 coutur
# 3 cover
# 1 cower
# 1 cowrot
# 2 cox
# 2 cq
# 6 crack
# 1 crackerjack
# 3 crackl
# 1 cradl
# 8 craft
# 1 craig
# 2 cram
# 1 crane
# 1 crap
# 1 crapul
# 3 crash
# 3 crass
# 1 crave
# 2 crawl
# 7 crazi
# 1 creaki
# 1 creami
# 17 creat
# 4 creation
# 13 creativ
# 4 creator
# 3 creatur
# 7 credibl
# 6 credit
# 2 credul
# 1 creed
# 1 creek
# 2 creep
# 8 creepi
# 1 creepiest
# 1 crematorium
# 1 crescendo
# 5 crew
# 1 cri
# 1 cria
# 1 cricket
# 15 crime
# 1 crimen
# 5 crimin
# 1 cring
# 1 crise
# 1 crisi
# 2 crisp
# 1 cristo
# 1 crit
# 5 critic
# 2 critiqu
# 1 croak
# 1 croatia
# 1 crocodil
# 1 cronenberg
# 1 crook
# 12 cross
# 2 crossroad
# 1 crotch
# 8 crowd
# 1 croze
# 2 crucial
# 6 crude
# 1 cruditi
# 1 crudup
# 2 cruel
# 1 cruelli
# 1 cruis
# 1 crummi
# 7 crush
# 2 crushingli
# 1 crypt
# 2 crystal
# 1 csoka
# 2 cuban
# 2 cube
# 1 cuddli
# 1 cuisin
# 2 culkin
# 2 cultiv
# 25 cultur
# 1 cunningham
# 1 curio
# 3 curios
# 2 curiou
# 1 curious
# 2 curmudgeon
# 1 currenc
# 4 current
# 1 cusack
# 1 cushion
# 1 cuss
# 1 customarili
# 8 cut
# 7 cute
# 1 cutoff
# 1 cutthroat
# 1 cyber
# 1 cycl
# 6 cynic
# 2 da
# 1 dabbl
# 4 dad
# 3 dahmer
# 2 daili
# 1 dainti
# 1 daisi
# 1 dalrympl
# 7 damag
# 11 damn
# 3 damon
# 1 danang
# 9 danc
# 6 danger
# 1 dangerfield
# 1 dani
# 2 daniel
# 1 danilo
# 2 danni
# 1 dant
# 1 daphn
# 8 dare
# 1 dario
# 26 dark
# 1 darkest
# 2 darkli
# 2 darn
# 1 darwinian
# 2 dass
# 8 date
# 1 dated
# 3 daught
# 4 daughter
# 2 davi
# 9 david
# 1 dawdl
# 2 dawn
# 3 dawson
# 27 day
# 4 daytim
# 1 daytime
# 1 daze
# 6 dazzl
# 19 de
# 16 dead
# 1 deadeningli
# 1 deadli
# 4 deadpan
# 8 deal
# 1 dealt
# 2 dean
# 3 dear
# 12 death
# 1 deathb
# 1 debas
# 4 debat
# 1 debloi
# 1 debri
# 1 debt
# 11 debut
# 6 decad
# 1 decay
# 1 deceit
# 10 decent
# 2 decept
# 4 decid
# 2 decidedli
# 1 decipher
# 3 decis
# 1 declin
# 1 deconstructionist
# 1 decter
# 2 dedic
# 2 deed
# 1 deem
# 9 deep
# 1 deepa
# 1 deepen
# 8 deeper
# 10 deepli
# 1 defeat
# 1 defens
# 3 defi
# 1 defianc
# 1 defiant
# 1 defiantli
# 1 deficit
# 2 defin
# 5 definit
# 1 deflat
# 1 deform
# 3 deft
# 4 deftli
# 1 degrad
# 4 degre
# 2 deja
# 2 del
# 1 delay
# 3 delet
# 1 delib
# 6 deliber
# 6 delic
# 1 delici
# 22 delight
# 1 deliri
# 1 delirium
# 26 deliv
# 3 deliveri
# 2 delus
# 1 delusion
# 3 delv
# 8 demand
# 1 demeanour
# 1 dement
# 1 demented
# 1 demi
# 5 demograph
# 4 demon
# 2 demonstr
# 12 deni
# 2 denial
# 1 deniro
# 1 denmark
# 1 denouement
# 5 dens
# 1 dentist
# 2 denzel
# 1 deok
# 1 depart
# 1 departur
# 8 depend
# 1 deperson
# 4 depict
# 1 deplet
# 1 deplor
# 2 deposit
# 4 deprav
# 10 depress
# 1 depressingli
# 9 depth
# 1 der
# 1 derid
# 4 deriv
# 2 derrida
# 1 derring
# 1 descend
# 1 descompromissado
# 6 describ
# 2 descript
# 13 deserv
# 1 desicc
# 12 design
# 6 desir
# 1 desol
# 2 despair
# 1 despairingli
# 11 desper
# 1 despis
# 29 despit
# 1 desplat
# 1 desta
# 5 destin
# 2 destini
# 2 destroy
# 2 destruct
# 1 detach
# 10 detail
# 1 detect
# 1 detent
# 1 deterior
# 10 determin
# 1 detract
# 1 detriment
# 3 deuc
# 4 devast
# 1 devastatingli
# 12 develop
# 1 development
# 2 deviant
# 3 devic
# 1 devil
# 1 devis
# 5 devoid
# 2 devolv
# 1 devot
# 1 diabol
# 1 dialog
# 22 dialogu
# 3 diari
# 1 diatrib
# 2 diaz
# 1 dick
# 2 dicken
# 1 dictat
# 1 didact
# 1 didactic
# 9 die
# 3 diesel
# 20 differ
# 9 difficult
# 4 dig
# 1 digest
# 2 digit
# 2 digniti
# 1 dilemma
# 1 dime
# 2 dimens
# 3 dimension
# 2 diminish
# 1 dimwit
# 3 dinner
# 1 diop
# 2 dip
# 1 diplomat
# 3 dire
# 39 direct
# 2 directli
# 80 director
# 4 directori
# 1 diretor
# 1 dirgelik
# 3 dirti
# 1 disabl
# 1 disaffected
# 1 disappear
# 10 disappoint
# 1 disappointingli
# 2 disast
# 4 disbelief
# 1 discard
# 2 discern
# 1 disciplin
# 1 disclos
# 1 disclosur
# 1 disco
# 1 disconnect
# 1 discont
# 1 discount
# 1 discourag
# 3 discov
# 4 discoveri
# 1 discurs
# 3 discuss
# 1 disdain
# 1 disgrac
# 7 disguis
# 5 disgust
# 1 dish
# 2 dishonest
# 1 dishonesti
# 2 disintegr
# 2 disjoint
# 2 dismal
# 1 dismantl
# 1 dismay
# 1 dismemb
# 3 dismiss
# 11 disney
# 1 dispassion
# 3 display
# 2 dispos
# 1 disposit
# 1 dispossess
# 1 disquiet
# 1 disquisit
# 1 diss
# 1 disservic
# 1 dissid
# 1 dissip
# 1 dissolut
# 1 dist
# 8 distanc
# 1 distil
# 7 distinct
# 1 distinctli
# 5 distinguish
# 2 distract
# 1 distress
# 6 disturb
# 1 disturbingli
# 2 dive
# 1 diverg
# 5 divers
# 3 divert
# 1 divertiss
# 1 divid
# 3 divin
# 1 divis
# 1 divorc
# 1 dixon
# 1 dizzi
# 1 djeinaba
# 3 do
# 1 doa
# 1 doc
# 1 doctor
# 5 document
# 39 documentari
# 1 documentary
# 1 dodder
# 109 doe
# 12 dog
# 2 dogma
# 1 dognini
# 1 dogtown
# 1 doing
# 1 doll
# 3 dollar
# 1 dollop
# 1 dolphin
# 1 doltish
# 3 domest
# 2 domin
# 1 domingo
# 1 don
# 1 donati
# 1 dond
# 22 done
# 2 dong
# 2 donovan
# 2 doo
# 1 doobi
# 1 doodl
# 1 doofu
# 2 door
# 1 doorstep
# 1 dope
# 1 dopey
# 1 dosag
# 5 dose
# 5 dot
# 2 doubl
# 2 double
# 5 doubt
# 1 doug
# 1 dougla
# 2 dour
# 1 dover
# 4 down
# 4 downbeat
# 2 downer
# 1 downfal
# 1 downhil
# 1 downplay
# 2 downright
# 1 downsiz
# 1 downtown
# 1 downy
# 1 doyl
# 2 doze
# 1 dozen
# 3 drab
# 1 drabli
# 1 draft
# 7 drag
# 6 dragon
# 2 dragonfli
# 3 drain
# 56 drama
# 21 dramat
# 1 dramatist
# 1 drang
# 7 draw
# 2 drawn
# 3 dread
# 9 dream
# 1 dreamlik
# 2 dreari
# 2 dreck
# 1 drek
# 1 drench
# 1 drenched
# 3 dress
# 1 drew
# 7 dri
# 2 drift
# 4 drink
# 1 drinker
# 1 drip
# 1 driv
# 9 drive
# 1 drivel
# 2 driven
# 1 driver
# 1 droll
# 1 drone
# 1 drool
# 3 drop
# 3 drown
# 1 drowsi
# 4 drug
# 2 drum
# 2 drumlin
# 3 drunk
# 2 drunken
# 1 dry
# 1 du
# 1 dub
# 1 dubiou
# 2 duck
# 5 dud
# 1 duddi
# 1 dude
# 6 due
# 2 duke
# 19 dull
# 1 dullest
# 3 duma
# 17 dumb
# 2 dumbed
# 2 dumber
# 1 dumbfoundingli
# 1 dummi
# 1 dump
# 1 dunc
# 1 dungeon
# 1 dungpil
# 1 dupe
# 8 dure
# 1 dust
# 1 dustbin
# 1 dustin
# 3 duti
# 1 duval
# 2 dvd
# 2 dwarf
# 1 dwell
# 1 dwindl
# 1 dylan
# 4 dynam
# 4 dysfunct
# 1 dyspept
# 1 dystopian
# 1 ear
# 3 earli
# 2 earlier
# 1 early
# 4 earn
# 10 earnest
# 1 earnestli
# 8 earth
# 1 earthi
# 1 earthli
# 1 earthshak
# 3 eas
# 18 easi
# 3 easier
# 12 easili
# 1 east
# 1 easter
# 1 eastern
# 2 eastwood
# 1 easy
# 2 eat
# 7 eccentr
# 1 ecclesiast
# 2 eck
# 1 eckstraordinarili
# 1 eclips
# 1 ecolog
# 3 econom
# 2 ed
# 1 eddi
# 10 edg
# 1 edge
# 1 edifi
# 10 edit
# 4 educ
# 1 eerili
# 41 effect
# 1 effects
# 3 effici
# 18 effort
# 1 effortlessli
# 1 effus
# 1 egg
# 1 egotist
# 1 egregi
# 4 eight
# 1 eileen
# 1 eisenstein
# 12 either
# 1 ejemplo
# 1 eke
# 3 el
# 4 elabor
# 1 elan
# 2 elbow
# 1 elder
# 2 elect
# 1 electr
# 1 electrocut
# 1 electron
# 4 eleg
# 3 elegantli
# 1 elegi
# 1 elegiac
# 6 element
# 1 elenco
# 1 eleph
# 3 elev
# 3 elicit
# 1 elit
# 4 elizabeth
# 2 ell
# 1 elli
# 1 elliott
# 2 ellipt
# 2 eloqu
# 15 els
# 1 else
# 2 elsewher
# 2 elus
# 1 elvi
# 3 em
# 1 email
# 1 embark
# 3 embarrass
# 1 embodi
# 5 embrac
# 5 emerg
# 1 emi
# 1 emin
# 1 emocionalment
# 46 emot
# 1 empathet
# 4 empathi
# 1 emperor
# 4 emphas
# 1 emphasi
# 4 empir
# 3 employ
# 2 empower
# 7 empti
# 1 en
# 1 enact
# 3 enchant
# 1 encompass
# 4 encount
# 3 encourag
# 67 end
# 1 endear
# 2 endeavor
# 1 endem
# 1 endgam
# 3 endless
# 2 endlessli
# 9 endur
# 3 enemi
# 2 energ
# 7 energet
# 16 energi
# 2 enerv
# 2 enforc
# 27 engag
# 2 engagingli
# 2 england
# 1 english
# 1 englishmen
# 1 engorg
# 7 engross
# 1 engulf
# 1 enhanc
# 2 enigma
# 41 enjoy
# 2 enlighten
# 1 enliven
# 1 ennui
# 8 enorm
# 73 enough
# 1 enraptur
# 2 enrich
# 6 ensembl
# 1 ensnar
# 1 ensu
# 1 ensur
# 3 enter
# 2 enterpris
# 67 entertain
# 2 enthral
# 1 enthron
# 1 enthus
# 2 enthusiasm
# 3 enthusiast
# 1 entic
# 18 entir
# 2 entranc
# 2 entri
# 1 entwin
# 2 envelop
# 1 enviou
# 1 environ
# 1 environment
# 14 epic
# 1 epilogu
# 10 episod
# 1 epitaph
# 1 eponym
# 1 epp
# 7 equal
# 3 equat
# 1 equilibrium
# 1 equip
# 7 equival
# 8 era
# 1 eras
# 1 erect
# 1 eric
# 1 erika
# 2 erot
# 1 erotic
# 1 errant
# 1 errat
# 1 errol
# 2 error
# 1 erupt
# 2 es
# 1 escal
# 5 escap
# 1 escapad
# 1 escort
# 1 esfera
# 1 esoter
# 15 especi
# 1 espetculo
# 1 espionag
# 1 espn
# 1 esqu
# 1 essay
# 1 essayist
# 5 essenti
# 1 establish
# 1 esteem
# 1 estela
# 1 esteticament
# 1 esther
# 1 estrogen
# 1 et
# 4 etc
# 2 ethan
# 3 ethic
# 5 ethnic
# 1 etoil
# 1 etr
# 1 eugen
# 1 eun
# 1 euro
# 2 european
# 1 ev
# 2 evad
# 1 evalu
# 1 evan
# 1 evapor
# 2 evelyn
# 110 even
# 12 event
# 5 eventu
# 39 ever
# 45 everi
# 2 everybodi
# 1 everyday
# 9 everyon
# 21 everyth
# 1 everytim
# 1 evid
# 1 evidenc
# 3 evil
# 3 evoc
# 7 evok
# 1 evolut
# 1 evolv
# 1 ex
# 12 exactli
# 3 exagger
# 1 exalt
# 12 examin
# 6 exampl
# 1 exasperatingli
# 1 exceed
# 1 exceedingli
# 9 excel
# 14 except
# 6 excess
# 13 excit
# 1 exclam
# 1 exclus
# 2 excruci
# 4 excus
# 15 execut
# 1 exemplari
# 12 exercis
# 3 exhaust
# 2 exhibit
# 5 exhilar
# 1 exhilaratingli
# 1 exhum
# 11 exist
# 3 existenti
# 2 exit
# 2 expand
# 1 expans
# 18 expect
# 1 expedi
# 24 experi
# 1 experienc
# 4 experiment
# 2 expertli
# 3 explain
# 2 explan
# 2 explicit
# 2 explod
# 14 exploit
# 10 explor
# 3 explos
# 1 expo
# 4 expos
# 3 exposit
# 1 exposur
# 1 expound
# 5 express
# 2 expressionist
# 1 expuls
# 1 exquisit
# 1 extant
# 5 extend
# 1 extens
# 2 extent
# 2 exterior
# 1 extra
# 1 extract
# 3 extraordinari
# 2 extraordinarili
# 3 extravaganza
# 13 extrem
# 2 extremist
# 1 exuber
# 2 exud
# 6 ey
# 19 eye
# 2 eyebal
# 1 eyeball
# 1 eyelid
# 1 eyr
# 1 fab
# 3 fabl
# 3 fabric
# 1 fabul
# 2 fac
# 1 facad
# 21 face
# 1 facet
# 1 facial
# 3 facil
# 1 facilit
# 15 fact
# 1 factor
# 1 fad
# 2 fade
# 1 fagioli
# 1 fahrenheit
# 16 fail
# 4 failur
# 1 faintli
# 5 fair
# 1 fairi
# 11 fairli
# 3 fairy
# 9 faith
# 5 fake
# 10 fall
# 3 fallen
# 1 fallon
# 3 fals
# 1 falsehood
# 1 falter
# 2 fame
# 32 famili
# 24 familiar
# 2 family
# 3 famou
# 23 fan
# 2 fanat
# 2 fanboy
# 4 fanci
# 1 fang
# 10 fantasi
# 1 fantasma
# 3 fantast
# 1 fantasti
# 39 far
# 2 farc
# 3 farcic
# 4 fare
# 1 farmer
# 2 farrelli
# 2 fart
# 22 fascin
# 11 fashion
# 7 fast
# 3 faster
# 3 fat
# 7 fatal
# 1 fatalist
# 5 fate
# 4 father
# 1 fathom
# 2 fault
# 1 faulti
# 1 faux
# 7 favor
# 3 favorit
# 1 favour
# 8 fear
# 3 feardotcom
# 1 fearless
# 2 feast
# 1 feat
# 4 feather
# 16 featur
# 4 feature
# 2 fece
# 1 fed
# 1 fee
# 2 feebl
# 92 feel
# 2 feet
# 1 fell
# 7 felt
# 11 femal
# 3 femin
# 1 feminin
# 4 feminist
# 1 femm
# 4 fenc
# 1 feroc
# 1 feroci
# 2 ferrara
# 1 fervent
# 3 fest
# 1 fester
# 3 festiv
# 2 fetish
# 1 fetishist
# 3 fewer
# 9 fi
# 1 fict
# 7 fiction
# 1 fide
# 2 fidel
# 2 field
# 1 fiend
# 2 fienn
# 4 fierc
# 3 fifti
# 6 fight
# 8 figur
# 1 fil
# 12 fill
# 1 filler
# 1 fillm
# 464 film
# 2 filmgoer
# 1 filmit
# 51 filmmak
# 15 final
# 2 fincher
# 34 find
# 1 finder
# 22 fine
# 1 finess
# 4 finest
# 1 fing
# 1 finger
# 8 finish
# 1 fiorentino
# 11 fire
# 1 firebrand
# 2 firmli
# 42 first
# 6 fish
# 3 fisher
# 1 fishi
# 1 fist
# 9 fit
# 6 five
# 1 fix
# 1 fizz
# 1 fizzl
# 1 flabbi
# 1 flaccid
# 1 flag
# 1 flagel
# 1 flail
# 3 flair
# 1 flaki
# 1 flam
# 1 flamboy
# 3 flame
# 3 flash
# 2 flashback
# 1 flashbulb
# 2 flashi
# 11 flat
# 1 flatbush
# 1 flatli
# 3 flatten
# 2 flatul
# 1 flaunt
# 1 flavor
# 1 flavorless
# 1 flavour
# 12 flaw
# 2 flee
# 2 fleet
# 2 flesh
# 8 fli
# 28 flick
# 1 flight
# 1 flim
# 1 flimsi
# 1 flinch
# 1 fling
# 3 flirt
# 3 float
# 2 flop
# 1 flotsam
# 2 flounder
# 3 flourish
# 3 flow
# 3 flower
# 1 fluctuat
# 4 fluff
# 1 fluid
# 2 fluke
# 1 flung
# 1 flux
# 2 focu
# 2 focus
# 2 foibl
# 8 folk
# 2 folli
# 15 follow
# 2 fond
# 3 fontain
# 5 food
# 6 fool
# 2 foolish
# 4 foot
# 5 footag
# 1 footbal
# 3 footnot
# 5 for
# 1 fora
# 26 forc
# 1 ford
# 1 foreground
# 5 foreign
# 1 forest
# 1 forev
# 6 forget
# 6 forgett
# 5 forgiv
# 1 forgo
# 1 forgot
# 2 forgotten
# 1 fork
# 16 form
# 1 formal
# 1 formalist
# 3 format
# 3 former
# 11 formula
# 1 formuliac
# 1 forster
# 1 fort
# 2 forth
# 1 forti
# 2 fortun
# 2 forward
# 1 foster
# 2 foul
# 10 found
# 2 foundat
# 1 founder
# 13 four
# 1 foursom
# 1 fourth
# 1 fragil
# 1 fragment
# 5 frailti
# 1 fram
# 10 frame
# 1 franc
# 1 francament
# 4 franchis
# 2 franco
# 1 francophil
# 1 frankenstein
# 1 frankli
# 2 franklin
# 1 franoi
# 2 frantic
# 2 fraser
# 2 frat
# 1 fratern
# 1 fray
# 1 frazzl
# 3 fre
# 2 freak
# 4 freaki
# 2 fred
# 6 free
# 1 freebi
# 3 freedom
# 1 frei
# 14 french
# 3 frenet
# 1 frenzi
# 5 frequent
# 13 fresh
# 1 freshen
# 1 freshman
# 1 fresnadillo
# 1 freudian
# 1 freundlich
# 1 frida
# 9 friday
# 1 friel
# 9 friend
# 2 friendli
# 6 friendship
# 3 frighten
# 1 frighteningli
# 1 frio
# 1 frodo
# 2 front
# 5 frontal
# 1 frontier
# 1 frontman
# 1 frosti
# 1 frothi
# 1 frown
# 1 frozen
# 2 fruit
# 6 frustrat
# 1 frustratingli
# 1 fu
# 1 fuddy
# 2 fudg
# 2 fuel
# 1 fuert
# 1 ful
# 2 fulfil
# 2 fulford
# 31 full
# 7 fulli
# 1 fulsom
# 2 fumbl
# 56 fun
# 1 funcionar
# 2 function
# 1 fundada
# 1 funk
# 83 funni
# 5 funnier
# 4 funniest
# 1 funnybon
# 1 furi
# 1 furious
# 1 furnish
# 1 fuse
# 1 fusion
# 1 fuss
# 1 futil
# 9 futur
# 1 future
# 1 futuro
# 4 fuzzi
# 1 ga
# 1 gadget
# 17 gag
# 1 gai
# 2 gain
# 2 gainsbourg
# 1 gaitskil
# 1 gal
# 1 galleri
# 1 gallo
# 1 galvan
# 15 game
# 1 gandalf
# 2 ganesh
# 6 gang
# 1 gangsta
# 6 gangster
# 1 ganha
# 2 gantz
# 1 gap
# 2 garbag
# 1 garbu
# 1 garca
# 2 garcia
# 1 gard
# 1 garish
# 1 garth
# 1 gasm
# 2 gasp
# 1 gather
# 1 gaug
# 1 gaul
# 4 gay
# 3 gayton
# 1 gaze
# 1 gear
# 1 gee
# 1 gel
# 1 gelo
# 7 gem
# 5 gender
# 1 gene
# 36 gener
# 1 generos
# 1 geneviev
# 1 genial
# 2 genit
# 21 genr
# 6 gentl
# 3 gentli
# 15 genuin
# 4 georg
# 1 gerbosi
# 2 geriatr
# 2 german
# 1 gestalt
# 95 get
# 1 ghastli
# 2 ghetto
# 6 ghost
# 1 ghostbust
# 1 ghoulish
# 1 giannini
# 6 giant
# 1 gibney
# 3 gibson
# 1 giddi
# 7 gift
# 1 gigant
# 2 giggl
# 1 giggle
# 1 giler
# 2 gilliam
# 1 gilligan
# 2 gimmick
# 3 gimmicki
# 1 girardot
# 22 girl
# 1 girls
# 50 give
# 13 given
# 1 glamor
# 2 glamour
# 1 glanc
# 4 glass
# 2 glib
# 1 glide
# 4 glimps
# 1 glint
# 1 glitz
# 2 glori
# 1 glorif
# 1 glorifi
# 1 gloriou
# 2 glorious
# 3 gloss
# 2 glossi
# 2 glu
# 2 glum
# 1 gnash
# 58 go
# 3 goal
# 1 gobbler
# 4 god
# 4 godard
# 1 goddammit
# 1 godfrey
# 2 godzilla
# 11 goe
# 1 goggl
# 2 gold
# 2 goldi
# 1 golf
# 7 gone
# 1 gong
# 1 goo
# 115 good
# 1 goodal
# 2 goodfella
# 1 goodi
# 2 goodwil
# 3 goofbal
# 5 goofi
# 6 gore
# 1 gorefest
# 10 gorgeou
# 2 gorgeous
# 3 gori
# 2 gosford
# 1 gosh
# 2 gosl
# 7 got
# 2 gothic
# 2 gotten
# 1 gourmet
# 1 govern
# 2 government
# 2 goyer
# 2 grab
# 10 grace
# 1 graceland
# 2 graceless
# 1 grad
# 4 grade
# 2 gradual
# 1 graffiti
# 1 graham
# 1 grain
# 2 graini
# 4 grand
# 3 grandeur
# 1 grandios
# 1 grandiosa
# 1 grandkid
# 1 grandli
# 1 grandpar
# 2 grandson
# 1 granger
# 3 grant
# 5 graphic
# 2 grasp
# 1 grass
# 3 grate
# 1 gratingli
# 1 gratitud
# 1 gratuit
# 1 grave
# 1 gravit
# 1 graviti
# 1 gray
# 1 grayish
# 1 greas
# 44 great
# 3 greater
# 8 greatest
# 2 greatli
# 1 greed
# 2 greedi
# 1 greek
# 9 green
# 1 greengrass
# 1 greenlight
# 1 greg
# 2 grenad
# 3 grew
# 2 grey
# 2 grief
# 1 griffin
# 1 griffith
# 4 grim
# 1 grimi
# 2 grimli
# 1 grin
# 3 grind
# 2 grinder
# 7 grip
# 2 grisli
# 6 gritti
# 1 grittili
# 1 groan
# 1 groaner
# 1 groen
# 6 gross
# 1 grossest
# 1 grossli
# 3 grotesqu
# 7 ground
# 1 groundbreak
# 6 group
# 2 groupi
# 11 grow
# 5 grown
# 1 gruesom
# 1 grumpi
# 1 grunge
# 1 grungi
# 6 guarante
# 1 guard
# 1 guei
# 3 guess
# 1 guest
# 1 guffaw
# 2 guid
# 2 guilt
# 5 guilti
# 1 guilty
# 1 guis
# 1 guitar
# 1 gulp
# 1 gum
# 2 gun
# 1 gunfight
# 1 gunplay
# 3 gut
# 15 guy
# 1 guzmn
# 186 ha
# 1 haber
# 1 hack
# 1 hackeri
# 4 hackney
# 1 hade
# 1 hagiograph
# 3 hair
# 1 hairdo
# 2 hal
# 23 half
# 1 halfheart
# 1 halftim
# 5 halfway
# 1 halfwit
# 1 hall
# 1 halloween
# 1 hallucinatori
# 1 hallucinogen
# 2 ham
# 1 hamfist
# 1 hamilton
# 2 hammer
# 2 hamper
# 22 hand
# 1 handgun
# 1 handheld
# 1 handiwork
# 6 handl
# 1 hands
# 4 hanek
# 1 hang
# 1 hank
# 1 hanna
# 1 hanussen
# 4 haphazard
# 1 hapless
# 11 happen
# 5 happi
# 2 happili
# 1 happily
# 1 happy
# 1 harbor
# 39 hard
# 1 harden
# 2 harder
# 1 hardest
# 1 hardi
# 6 hardli
# 1 hardman
# 1 hardwar
# 1 hare
# 2 harm
# 7 harmless
# 1 harmon
# 1 harmoni
# 8 harri
# 4 harrow
# 3 harsh
# 2 hart
# 3 hartley
# 7 harvard
# 1 harvey
# 1 hashiguchi
# 3 hat
# 6 hate
# 1 hatfield
# 1 hatosi
# 2 hatr
# 10 haunt
# 1 haut
# 1 have
# 1 hawaiian
# 7 hawk
# 3 hawn
# 4 hayn
# 18 head
# 1 headach
# 1 headi
# 1 headlin
# 1 heal
# 1 health
# 3 hear
# 3 heard
# 1 hearst
# 48 heart
# 2 heartach
# 1 heartbeat
# 4 heartbreak
# 2 heartbreakingli
# 1 hearten
# 6 heartfelt
# 1 heartili
# 1 heartland
# 2 heartstr
# 6 heartwarm
# 4 heat
# 4 heaven
# 14 heavi
# 2 heavili
# 8 heavy
# 1 heavyweight
# 2 heck
# 1 hectic
# 2 heel
# 1 heft
# 1 heidi
# 2 height
# 2 heighten
# 1 heinou
# 1 heist
# 7 held
# 1 helga
# 10 hell
# 1 hellish
# 1 helm
# 25 help
# 1 henri
# 1 her
# 1 herd
# 1 heritag
# 1 hermet
# 14 hero
# 1 heroic
# 3 heroin
# 4 herzog
# 2 hewitt
# 3 hey
# 1 heyday
# 134 hi
# 1 hiatu
# 1 hibiscu
# 1 hick
# 1 hickenloop
# 1 hidden
# 3 hide
# 1 hideous
# 1 hierarchi
# 26 high
# 2 higher
# 2 highest
# 5 highli
# 1 highlight
# 1 highly
# 1 highway
# 1 hijack
# 2 hilar
# 9 hilari
# 1 hile
# 5 hill
# 1 hindsight
# 2 hing
# 2 hint
# 10 hip
# 1 hire
# 9 histor
# 21 histori
# 1 historia
# 1 histrion
# 21 hit
# 1 hitchcock
# 1 hitler
# 1 hitmen
# 1 hiv
# 1 hjelj
# 1 hlne
# 1 ho
# 1 hoari
# 1 hobbl
# 1 hobnail
# 1 hodgepodg
# 6 hoffman
# 1 hokey
# 3 hokum
# 12 hold
# 1 holden
# 8 hole
# 2 holi
# 6 holiday
# 1 holli
# 1 hollow
# 41 hollywood
# 4 holm
# 2 holocaust
# 1 holofcen
# 1 holograph
# 1 hom
# 4 homag
# 17 home
# 1 homicid
# 1 homo
# 1 homogen
# 2 hon
# 13 honest
# 4 honesti
# 2 honestli
# 1 honey
# 3 hong
# 2 honor
# 1 hood
# 5 hop
# 18 hope
# 1 hopeless
# 1 hopelessli
# 3 hopkin
# 1 hopkins
# 1 horizon
# 1 hornbi
# 4 horribl
# 2 horrid
# 3 horrifi
# 22 horror
# 3 hors
# 1 hossein
# 2 host
# 1 hostess
# 1 hostil
# 4 hot
# 1 hotdog
# 1 hotel
# 1 hotsi
# 1 hotter
# 27 hour
# 5 hous
# 1 household
# 5 howard
# 11 howev
# 1 howl
# 2 howler
# 1 hubac
# 1 hudlin
# 1 hug
# 4 huge
# 2 hugh
# 1 hum
# 33 human
# 1 humanli
# 3 humbl
# 1 humdrum
# 1 humid
# 1 humili
# 41 humor
# 2 humorless
# 4 humour
# 1 hundr
# 3 hungri
# 1 hunk
# 2 hunt
# 1 hunter
# 4 huppert
# 3 hurley
# 3 hurri
# 1 hurt
# 4 husband
# 1 hush
# 2 huski
# 2 hustler
# 1 hutchin
# 5 hybrid
# 1 hype
# 2 hyper
# 1 hyperbol
# 1 hypnot
# 2 hypocrisi
# 1 hyster
# 1 hysteria
# 1 ia
# 1 ian
# 1 iben
# 4 ice
# 1 ichi
# 1 iconoclast
# 33 idea
# 4 ideal
# 1 idealist
# 1 idemoto
# 5 ident
# 1 ideolog
# 1 idiosyncrasi
# 1 idiosyncrat
# 5 idiot
# 1 idol
# 1 idoosyncrat
# 3 if
# 1 igloo
# 1 ignit
# 5 ignor
# 9 ii
# 1 ikea
# 1 ilk
# 8 ill
# 1 illicit
# 1 illiter
# 2 illog
# 1 illumin
# 2 illus
# 3 illustr
# 1 ilya
# 18 imag
# 1 image
# 5 imageri
# 28 imagin
# 1 imaginari
# 7 imax
# 1 imbu
# 3 imit
# 1 immacul
# 2 immatur
# 3 immedi
# 1 immediaci
# 7 immens
# 1 immers
# 2 immigr
# 1 immor
# 1 immun
# 7 impact
# 1 impass
# 4 impecc
# 2 impenetr
# 1 imperfect
# 4 imperson
# 2 impish
# 2 implaus
# 4 impli
# 1 implic
# 2 implicit
# 1 implicitli
# 1 implod
# 14 import
# 1 importa
# 2 importantli
# 1 impos
# 9 imposs
# 1 impost
# 2 impostor
# 23 impress
# 6 improb
# 4 improv
# 5 improvis
# 1 impuls
# 14 in
# 1 inact
# 3 inadvert
# 6 inan
# 1 inarticul
# 1 incap
# 2 incarn
# 1 incess
# 1 incessantli
# 1 inch
# 3 incid
# 1 incis
# 6 includ
# 1 incognito
# 7 incoher
# 3 incompet
# 1 incomprehens
# 2 incongru
# 2 inconsequenti
# 4 inconsist
# 2 incorpor
# 1 increas
# 3 increasingli
# 3 incred
# 11 inde
# 1 indel
# 3 independ
# 1 indescrib
# 5 indi
# 3 indian
# 4 indic
# 3 indict
# 2 indie
# 1 indigen
# 2 indistinct
# 5 individu
# 1 indoor
# 4 induc
# 1 inducingli
# 13 indulg
# 7 industri
# 1 ineff
# 1 ineleg
# 9 inept
# 1 inequ
# 3 inert
# 2 inertia
# 2 inescap
# 3 inevit
# 1 inexcus
# 2 inexor
# 1 inexperienc
# 4 inexplic
# 1 inextric
# 1 infami
# 1 infant
# 1 infantil
# 1 infatu
# 3 infecti
# 2 inferior
# 1 infiltr
# 1 infinit
# 1 inflat
# 1 inflict
# 6 influenc
# 1 influenti
# 2 infomerci
# 3 inform
# 2 infuri
# 2 infus
# 2 ingeni
# 1 ingenu
# 4 ingredi
# 5 inher
# 1 inhospit
# 4 initi
# 1 inject
# 2 injuri
# 1 injustic
# 1 ink
# 1 inmat
# 4 inner
# 1 innoc
# 1 innocu
# 3 innov
# 4 inoffens
# 1 inquisit
# 2 insan
# 1 inscrut
# 2 insecur
# 1 insensit
# 6 insid
# 1 inside
# 19 insight
# 2 insignific
# 2 insipid
# 3 insist
# 3 insomnia
# 24 inspir
# 3 instal
# 1 instanc
# 3 instantli
# 22 instead
# 4 instinct
# 2 instruct
# 1 insuffici
# 3 insult
# 1 insur
# 1 intacto
# 5 integr
# 2 intellect
# 4 intellectu
# 28 intellig
# 6 intend
# 11 intens
# 9 intent
# 1 inter
# 2 interact
# 2 interesant
# 48 interest
# 2 interestingli
# 1 interfaith
# 2 interior
# 1 interlock
# 2 interlud
# 1 intermin
# 1 intermiss
# 5 intermitt
# 1 intern
# 1 interplay
# 5 interpret
# 1 interrupt
# 1 interspl
# 3 interview
# 1 interweav
# 8 intim
# 1 intimaci
# 2 intoler
# 1 intox
# 1 intoxicatingli
# 4 intric
# 19 intrigu
# 1 intro
# 3 introduct
# 1 introspect
# 1 inv
# 3 invalu
# 11 invent
# 2 invest
# 1 investig
# 2 invigor
# 1 invinc
# 4 invit
# 1 invok
# 6 involv
# 1 involvingli
# 1 invulner
# 1 iota
# 3 iran
# 7 iranian
# 1 iraqi
# 1 ireland
# 4 irish
# 6 iron
# 2 ironi
# 1 irrat
# 1 irrelev
# 1 irrepress
# 5 irresist
# 1 irrespons
# 1 irrever
# 2 irrevoc
# 6 irrit
# 2 irritatingli
# 1 irvin
# 2 irwin
# 1 ish
# 2 island
# 2 isol
# 1 israeli
# 5 issu
# 1 it
# 1 italian
# 1 item
# 1 iter
# 1 itiner
# 1 ivi
# 1 ivori
# 2 jack
# 1 jackal
# 1 jackass
# 5 jacki
# 9 jackson
# 2 jacqu
# 2 jacquot
# 1 jae
# 1 jag
# 1 jagger
# 1 jaglom
# 1 jakob
# 4 jame
# 3 jane
# 1 janic
# 1 januari
# 1 japan
# 6 japanes
# 4 jar
# 1 jarecki
# 1 jarvi
# 6 jason
# 1 jaunti
# 2 jay
# 1 jazz
# 1 jazzi
# 3 jealousi
# 1 jean
# 1 jelinek
# 2 jell
# 2 jennif
# 1 jeong
# 2 jersey
# 1 jewish
# 1 jez
# 2 jfk
# 1 jia
# 1 jie
# 1 jim
# 1 jir
# 1 jiri
# 3 joan
# 1 joaquin
# 9 job
# 3 joe
# 2 joel
# 1 joff
# 15 john
# 1 join
# 3 jok
# 14 joke
# 1 joker
# 2 joli
# 1 jolli
# 4 jolt
# 2 jon
# 2 jonah
# 3 jone
# 1 joo
# 1 joseph
# 1 jostl
# 1 journal
# 2 journalist
# 12 journey
# 1 jovial
# 1 jovovich
# 8 joy
# 2 joyless
# 1 jr
# 1 judaism
# 1 judd
# 2 judg
# 1 judgment
# 3 juic
# 1 julia
# 1 juliann
# 1 juliet
# 1 juliett
# 4 jump
# 1 jumpsuit
# 1 junctur
# 1 junior
# 5 junk
# 1 junki
# 1 just
# 3 justic
# 3 justifi
# 2 juvenil
# 1 juwanna
# 1 juxtaposit
# 2 kafka
# 1 kahn
# 1 kaleidoscop
# 1 kao
# 6 kapur
# 1 karmen
# 1 kasem
# 1 kathryn
# 1 katz
# 3 kaufman
# 1 kazmierski
# 2 keen
# 1 keenest
# 1 keenli
# 47 keep
# 1 ken
# 1 kendal
# 2 kennedi
# 2 kept
# 2 kevin
# 10 key
# 1 ki
# 1 kibbitz
# 4 kick
# 1 kickass
# 25 kid
# 3 kiddi
# 1 kidlet
# 1 kidman
# 1 kidnap
# 1 kidnapp
# 1 kids
# 1 kieran
# 1 kieslowski
# 1 kil
# 9 kill
# 7 killer
# 2 kilmer
# 5 kilt
# 3 kim
# 42 kind
# 2 kinda
# 1 kinet
# 4 king
# 2 kingdom
# 3 kinki
# 1 kinnear
# 1 kirkegaard
# 1 kirshner
# 4 kiss
# 6 kissing
# 2 kitsch
# 1 kitschi
# 1 kitten
# 1 klein
# 1 kline
# 1 knack
# 2 knee
# 2 knew
# 1 knit
# 1 knockaround
# 1 knot
# 24 know
# 1 knowing
# 1 knowingli
# 3 knowledg
# 2 known
# 1 knuckl
# 2 koepp
# 3 kong
# 1 kooki
# 1 kool
# 3 korean
# 1 kosashvili
# 3 kosminski
# 1 kouri
# 5 kung
# 1 kuri
# 1 kurt
# 1 kwan
# 2 la
# 2 labor
# 1 labour
# 2 labut
# 1 labyrinthin
# 1 lace
# 1 lacer
# 36 lack
# 1 lackadais
# 5 lacklust
# 2 lad
# 2 ladder
# 1 laddish
# 1 laden
# 4 ladi
# 1 lag
# 1 laid
# 1 laissez
# 1 lake
# 9 lame
# 1 lampoon
# 3 lan
# 6 land
# 2 landmark
# 1 landscap
# 3 lane
# 4 languag
# 2 languid
# 2 languor
# 2 lapaglia
# 1 larami
# 1 lard
# 12 larg
# 1 large
# 1 larger
# 1 larri
# 1 larson
# 1 lasker
# 20 last
# 6 late
# 1 latent
# 1 later
# 9 latest
# 1 latifah
# 1 latin
# 2 latino
# 3 latter
# 1 lau
# 1 laudabl
# 29 laugh
# 2 laughabl
# 3 laughter
# 1 laundri
# 2 lavish
# 2 lavishli
# 2 law
# 3 lawrenc
# 1 lax
# 1 lay
# 2 layer
# 8 lazi
# 1 lazier
# 23 lead
# 1 leaden
# 1 leader
# 1 leagu
# 3 leak
# 1 leaki
# 1 lean
# 2 leap
# 6 learn
# 32 least
# 1 leather
# 21 leav
# 2 leaven
# 1 leavitt
# 1 lector
# 2 lectur
# 2 led
# 3 lee
# 17 left
# 2 leg
# 2 legal
# 1 legendari
# 2 legitim
# 3 leigh
# 1 leisur
# 2 lend
# 8 length
# 1 lenienc
# 2 leon
# 1 leonard
# 1 leonin
# 1 leplouff
# 1 leroy
# 25 less
# 1 lessen
# 1 lesser
# 7 lesson
# 15 let
# 2 letdown
# 2 lethal
# 1 letharg
# 2 letter
# 1 letterman
# 1 leukemia
# 16 level
# 1 levi
# 3 lewi
# 1 ley
# 1 liabil
# 1 liana
# 1 liang
# 2 liar
# 1 lib
# 8 liber
# 1 liberti
# 1 librari
# 2 librarian
# 1 libretto
# 1 licens
# 3 lie
# 3 lif
# 64 life
# 3 lifeless
# 1 lifelong
# 4 lifestyl
# 5 lift
# 21 light
# 2 lighten
# 2 lighter
# 1 lightest
# 2 lightheart
# 2 lightweight
# 5 lik
# 1 lika
# 6 likabl
# 207 like
# 1 likeabl
# 2 lil
# 2 lilia
# 3 lillard
# 1 lilo
# 1 liman
# 2 limb
# 10 limit
# 2 limp
# 1 limpid
# 1 linda
# 22 line
# 1 liner
# 4 linger
# 1 lingual
# 1 linguist
# 2 link
# 1 linklat
# 2 lion
# 3 liotta
# 6 lip
# 1 lipstick
# 1 lise
# 6 list
# 1 listen
# 2 listless
# 4 lit
# 1 lite
# 6 liter
# 2 literari
# 85 littl
# 1 little
# 2 liv
# 48 live
# 1 liven
# 27 ll
# 5 lo
# 3 load
# 2 loath
# 1 loathsom
# 1 lobbi
# 1 local
# 2 locat
# 2 lodg
# 1 lofti
# 1 log
# 8 logic
# 1 lohman
# 1 lolita
# 1 london
# 2 lone
# 3 loneli
# 54 long
# 8 longer
# 89 look
# 1 lookin
# 1 loop
# 1 loophol
# 5 loos
# 1 loosely
# 3 lopez
# 1 lord
# 1 los
# 8 lose
# 6 loss
# 9 lost
# 45 lot
# 9 loud
# 1 loui
# 1 louis
# 1 louiso
# 2 lousi
# 1 lovabl
# 1 lovable
# 67 love
# 4 lover
# 1 lovers
# 1 lovingli
# 18 low
# 2 lowbrow
# 3 loyal
# 2 ltimo
# 2 luca
# 3 lucki
# 1 luckiest
# 3 ludicr
# 1 lukewarm
# 1 lull
# 1 lullabi
# 2 lumber
# 1 lumin
# 2 lump
# 1 lumpen
# 1 lunaci
# 1 lunar
# 1 lunat
# 2 lunch
# 2 luridli
# 1 lurk
# 1 lusciou
# 4 lush
# 1 lustrou
# 1 luther
# 1 luv
# 5 lyric
# 2 macabr
# 1 macdowel
# 5 machin
# 3 machismo
# 2 maci
# 9 mad
# 2 madden
# 48 made
# 4 madonna
# 1 maelstrom
# 1 mag
# 1 maggot
# 6 magic
# 1 magimel
# 1 magnet
# 2 magnific
# 1 magnifiqu
# 1 magnolia
# 1 mai
# 3 maid
# 1 maiden
# 1 maik
# 4 main
# 4 mainli
# 2 mainstream
# 9 maintain
# 1 mainten
# 1 majesti
# 2 majidi
# 6 major
# 1 mak
# 161 make
# 6 maker
# 2 makhmalbaf
# 1 malarkey
# 1 malcolm
# 4 male
# 1 malfitano
# 1 malic
# 4 malkovich
# 2 mall
# 1 malleabl
# 1 malnourish
# 1 malnutrit
# 1 mam
# 1 mama
# 1 mamet
# 27 man
# 1 mana
# 27 manag
# 1 manchild
# 1 mandat
# 1 mandi
# 3 manhattan
# 1 manhood
# 41 mani
# 1 mania
# 1 maniac
# 5 manipul
# 1 mann
# 11 manner
# 2 manufactur
# 1 mapquest
# 2 mar
# 1 marathon
# 2 march
# 2 margin
# 6 mari
# 1 marin
# 1 marina
# 1 marine
# 11 mark
# 1 markedli
# 1 marker
# 7 market
# 1 marque
# 2 marri
# 3 marriag
# 5 martial
# 3 martin
# 1 martyr
# 4 marvel
# 1 marxian
# 1 mary
# 2 maryam
# 1 masculin
# 4 mask
# 2 masoch
# 2 mason
# 1 mass
# 2 massacr
# 1 masseur
# 15 master
# 5 masterpiec
# 1 mat
# 9 match
# 1 mate
# 1 mater
# 38 materi
# 1 matey
# 2 matine
# 2 matrix
# 1 matt
# 1 mattei
# 23 matter
# 4 matthew
# 1 matur
# 4 maudlin
# 1 maverick
# 2 max
# 1 maxim
# 2 maximum
# 54 may
# 7 mayb
# 4 mayhem
# 1 mcbeal
# 1 mccoist
# 1 mcconaughey
# 1 mcdowel
# 1 mcfarlan
# 2 mcgrath
# 3 mckay
# 1 mcmullen
# 1 mctiernan
# 3 meal
# 26 mean
# 4 meander
# 2 meaning
# 2 meaningless
# 3 meant
# 1 meanwhil
# 1 meara
# 5 measur
# 2 meat
# 1 meatbal
# 6 mechan
# 1 meddl
# 3 media
# 1 medicin
# 7 mediocr
# 4 medit
# 4 medium
# 7 meet
# 2 meets
# 1 megaplex
# 1 mehta
# 1 meinhof
# 1 mel
# 1 melancholi
# 1 melancholia
# 1 melang
# 17 melodrama
# 5 melodramat
# 1 melt
# 1 melvil
# 1 memb
# 9 member
# 1 memento
# 1 memoir
# 12 memor
# 14 memori
# 1 memory
# 13 men
# 5 menac
# 2 mend
# 3 mental
# 5 mention
# 1 menzel
# 1 merchant
# 1 merci
# 12 mere
# 1 merg
# 1 merger
# 1 mesh
# 8 mesmer
# 1 mesmeris
# 14 mess
# 16 messag
# 1 message
# 2 messi
# 1 met
# 8 metaphor
# 1 metaphys
# 1 method
# 1 methodolog
# 1 meticul
# 1 metropoli
# 1 metropolitan
# 1 mettl
# 11 michael
# 3 michel
# 1 michl
# 1 mick
# 1 microcosm
# 2 mid
# 6 middl
# 2 middle
# 1 midlevel
# 2 midnight
# 1 midriff
# 37 might
# 1 mighti
# 1 miik
# 4 mike
# 3 mil
# 3 mild
# 10 mildli
# 6 mile
# 1 milieu
# 2 militari
# 2 milk
# 1 mill
# 2 miller
# 4 million
# 1 mimicri
# 35 mind
# 5 mindless
# 2 mine
# 1 ming
# 1 minim
# 2 minimum
# 1 minkoff
# 1 minni
# 3 minor
# 2 minu
# 43 minut
# 1 minutes
# 1 miracl
# 1 miracul
# 1 miramax
# 2 mire
# 1 mirthless
# 1 misdemeanor
# 3 miser
# 1 miseri
# 1 misfir
# 1 misfortun
# 1 misguid
# 3 mishmash
# 1 mislead
# 1 misogynist
# 1 mispercept
# 20 miss
# 2 mission
# 1 mississippi
# 1 missiv
# 1 mist
# 3 mistak
# 1 mistakenli
# 1 mitch
# 9 mix
# 1 mixer
# 3 mixtur
# 2 miyazaki
# 1 mnch
# 2 mo
# 1 mobil
# 1 mobiu
# 1 mock
# 1 mockumentari
# 1 mode
# 2 model
# 1 moder
# 22 modern
# 3 modest
# 1 mohawk
# 1 moist
# 1 moistur
# 1 molder
# 2 moldi
# 1 molest
# 2 mom
# 43 moment
# 2 momento
# 4 momentum
# 1 mommi
# 1 monarch
# 1 monast
# 6 money
# 1 mong
# 2 monkey
# 1 monopoli
# 1 monoton
# 1 monro
# 3 monsoon
# 6 monster
# 1 monstrous
# 1 mont
# 1 month
# 3 monti
# 1 monument
# 13 mood
# 4 moodi
# 1 moodili
# 1 moonlight
# 5 moor
# 1 moot
# 1 moppet
# 16 moral
# 1 moralist
# 2 morgan
# 1 morlock
# 1 morri
# 1 morrison
# 1 mortal
# 1 mortarboard
# 2 morton
# 3 morvern
# 10 mostli
# 7 mother
# 1 motherhood
# 2 mothman
# 1 motif
# 4 motion
# 6 motiv
# 1 motocross
# 1 motorcycl
# 4 motown
# 3 mount
# 2 mourn
# 1 mous
# 1 moustach
# 4 mouth
# 1 mouthpiec
# 4 mov
# 30 move
# 6 movement
# 381 movi
# 3 movie
# 11 moviego
# 6 moviemak
# 1 movingli
# 12 mr
# 9 ms
# 2 mtv
# 3 muccino
# 107 much
# 1 muckrak
# 1 mud
# 3 muddl
# 1 mull
# 1 mullan
# 2 multi
# 2 multiplex
# 1 mumbl
# 1 mummifi
# 2 mundan
# 7 murder
# 4 murki
# 1 murkiest
# 4 murphi
# 1 mus
# 2 muse
# 1 museum
# 1 mush
# 1 mushi
# 29 music
# 3 musician
# 2 musket
# 1 musset
# 13 must
# 1 musti
# 4 mute
# 1 mutter
# 1 muzak
# 18 mysteri
# 1 mystery
# 2 mystic
# 3 mytholog
# 1 nadir
# 1 nailbit
# 1 nair
# 1 nakata
# 1 naked
# 14 name
# 1 nanosecond
# 1 nap
# 1 napoleon
# 1 naptim
# 3 narc
# 2 narciss
# 1 narcissist
# 1 narcot
# 20 narr
# 3 narrat
# 1 narrow
# 6 nasti
# 1 natali
# 4 nation
# 1 nationalist
# 1 nativ
# 1 natter
# 19 natur
# 1 naturalist
# 2 naughti
# 1 nauseat
# 1 nauseatingli
# 9 near
# 12 nearli
# 1 neat
# 1 neatli
# 3 necessari
# 2 necessarili
# 1 neck
# 24 need
# 1 needi
# 1 needl
# 2 needlessli
# 1 neeson
# 2 neg
# 1 negar
# 2 neglect
# 1 neglig
# 1 negoti
# 1 neighborhood
# 2 neil
# 16 neither
# 1 nelson
# 1 nemesi
# 1 neo
# 5 nerv
# 1 nerve
# 3 nervi
# 4 nervou
# 1 nesbitt
# 1 nettelbeck
# 1 network
# 1 neurasthen
# 1 neuros
# 70 never
# 2 neverland
# 2 nevertheless
# 38 new
# 1 newcastl
# 1 newfangl
# 1 newli
# 4 news
# 17 next
# 1 niccol
# 10 nice
# 3 nich
# 2 nichola
# 1 nicholson
# 1 nick
# 2 nicklebi
# 1 nicol
# 1 nicola
# 1 nifti
# 7 night
# 1 nightclub
# 4 nightmar
# 3 nijinski
# 2 nimbl
# 1 nincompoop
# 2 nine
# 1 nineti
# 7 niro
# 1 nit
# 1 nobl
# 1 nobodi
# 3 nod
# 1 nohe
# 2 noir
# 2 nois
# 1 nolan
# 5 nomin
# 7 non
# 1 nonbeliev
# 1 nonchalleng
# 1 nonconform
# 10 none
# 3 nonetheless
# 1 nonfict
# 2 nonjudgment
# 1 nonprofession
# 9 nonsens
# 1 nonstop
# 1 nonthreaten
# 1 noodl
# 1 norm
# 1 norma
# 2 normal
# 1 norri
# 1 northern
# 1 norton
# 3 nose
# 1 nostalg
# 2 nostalgia
# 4 not
# 2 notabl
# 6 notch
# 5 note
# 59 noth
# 6 notic
# 3 notion
# 3 notori
# 1 nourish
# 1 novak
# 15 novel
# 1 novic
# 1 nowaday
# 5 nowher
# 1 nowheresvil
# 1 noxiou
# 4 noyc
# 2 nuanc
# 1 nubil
# 2 nuclear
# 1 nude
# 2 nuditi
# 5 numb
# 11 number
# 3 numbingli
# 4 numer
# 1 nut
# 1 nutti
# 1 nymphett
# 1 oafish
# 3 object
# 3 obligatori
# 1 oblivi
# 1 oblivion
# 2 obnoxi
# 4 obscur
# 10 observ
# 4 obsess
# 1 obsessive
# 1 obstacl
# 1 obviat
# 17 obviou
# 4 obvious
# 1 occas
# 16 occasion
# 1 occupi
# 2 occur
# 1 occurr
# 1 octan
# 1 octopu
# 9 odd
# 2 oddest
# 1 odditi
# 5 oddli
# 2 odor
# 1 odyssey
# 3 oedekerk
# 1 oeuvr
# 19 of
# 10 off
# 4 offbeat
# 1 offend
# 2 offens
# 36 offer
# 3 offic
# 1 offici
# 1 ofrecen
# 34 often
# 3 oh
# 1 ohling
# 1 oil
# 1 ok
# 36 old
# 1 older
# 1 ole
# 2 oliv
# 2 oliveira
# 1 olivi
# 1 omit
# 9 on
# 20 onc
# 196 one
# 84 onli
# 1 only
# 4 onscreen
# 3 onto
# 1 oo
# 5 ooz
# 1 op
# 1 opac
# 2 opaqu
# 14 open
# 1 oper
# 15 opera
# 1 opinion
# 1 opium
# 10 opportun
# 1 oppos
# 1 opposit
# 2 oppress
# 2 oprah
# 1 optic
# 3 optim
# 2 optimist
# 1 option
# 1 opul
# 1 oral
# 3 orang
# 1 orchard
# 1 orchestr
# 2 ordeal
# 6 order
# 5 ordinari
# 3 organ
# 1 orgasm
# 1 orgi
# 3 ori
# 26 origin
# 1 orlando
# 13 oscar
# 1 oscura
# 13 otherwis
# 1 otherworldli
# 2 ought
# 1 ounc
# 1 ouro
# 3 ourselv
# 12 out
# 3 outburst
# 3 outer
# 1 outgag
# 2 outing
# 1 outnumb
# 6 outrag
# 1 outright
# 1 outsel
# 2 outshin
# 6 outsid
# 1 outstand
# 1 outta
# 1 outtak
# 1 outward
# 2 outweigh
# 2 ov
# 7 over
# 1 overact
# 13 overal
# 1 overbear
# 1 overburden
# 7 overcom
# 1 overcook
# 1 overdos
# 1 overdu
# 2 overh
# 1 overhear
# 1 overindulg
# 1 overinfl
# 4 overli
# 2 overlong
# 1 overly
# 1 overplay
# 1 overrid
# 1 overrip
# 2 overs
# 1 oversex
# 3 overshadow
# 2 overst
# 1 overstay
# 1 overstimul
# 1 overstuf
# 1 overtim
# 6 overwhelm
# 1 overwhelmingli
# 9 overwrought
# 1 owe
# 1 own
# 2 owner
# 1 ozpetek
# 1 pabst
# 3 pac
# 16 pace
# 3 pacino
# 12 pack
# 2 packag
# 1 pact
# 3 pad
# 1 padr
# 1 paean
# 1 page
# 1 pageantri
# 4 paid
# 14 pain
# 1 painless
# 4 paint
# 3 pair
# 1 pal
# 1 palestinian
# 2 palma
# 1 paltrow
# 1 pamela
# 1 pan
# 3 panach
# 1 pander
# 2 panoram
# 3 pant
# 1 pantheon
# 1 pantomimesqu
# 1 papa
# 5 paper
# 1 papin
# 1 para
# 5 parabl
# 1 parad
# 1 paradigm
# 1 paradiso
# 3 parallel
# 1 paranoia
# 11 parent
# 1 pari
# 5 park
# 1 parka
# 4 parker
# 5 parodi
# 1 parrot
# 22 part
# 4 parti
# 1 particip
# 2 participatori
# 3 particular
# 10 particularli
# 2 partli
# 2 partway
# 1 pasolini
# 5 pass
# 1 passabl
# 1 passag
# 1 passatempo
# 1 passer
# 18 passion
# 1 passiv
# 1 passive
# 15 past
# 1 pasta
# 1 pasti
# 2 pastich
# 1 pastri
# 1 pat
# 2 patch
# 4 path
# 3 pathet
# 3 patho
# 4 patholog
# 3 patienc
# 2 patient
# 1 patric
# 2 patron
# 1 patter
# 1 pattern
# 2 paul
# 2 paulett
# 2 paulin
# 1 paus
# 1 paxton
# 9 pay
# 4 payoff
# 1 pea
# 2 peac
# 2 peak
# 1 pearl
# 1 peculiar
# 1 pedagogi
# 1 peddl
# 1 pedest
# 2 pedestrian
# 1 pedigre
# 1 pedro
# 2 peek
# 1 peevish
# 1 pelcula
# 2 pellington
# 1 pelosi
# 1 pen
# 1 penalti
# 1 penetr
# 1 penn
# 47 peopl
# 2 peplo
# 2 pepper
# 1 per
# 1 perabo
# 1 peralta
# 1 percept
# 1 percol
# 1 percuss
# 3 perdit
# 1 perdo
# 8 perfect
# 8 perfectli
# 101 perform
# 10 perhap
# 5 peril
# 9 period
# 1 perki
# 2 permeat
# 1 permit
# 2 perpetu
# 1 perplex
# 1 perri
# 2 persist
# 1 persnicketi
# 18 person
# 7 persona
# 2 personifi
# 2 perspect
# 2 persuas
# 3 pertin
# 1 pervas
# 3 pervers
# 1 peski
# 3 pessimist
# 1 pete
# 5 peter
# 1 petti
# 2 pg
# 1 phantom
# 2 phenomen
# 1 philand
# 2 philip
# 2 phillip
# 3 philosoph
# 4 philosophi
# 1 phoenix
# 1 phonc
# 1 phone
# 1 phoney
# 1 phoni
# 1 photo
# 1 photograph
# 4 photographi
# 2 phrase
# 5 physic
# 1 physiqu
# 3 pianist
# 4 piano
# 5 pic
# 4 piccoli
# 2 pick
# 1 picki
# 1 picnic
# 39 pictur
# 5 pie
# 29 piec
# 1 piesiewicz
# 2 piffl
# 6 pile
# 1 pileup
# 1 pilot
# 1 piment
# 1 pin
# 1 pine
# 3 pinocchio
# 1 pinochet
# 1 pint
# 1 pipe
# 1 piper
# 1 piquant
# 1 pir
# 1 piss
# 1 pistol
# 1 pit
# 3 pitch
# 3 piti
# 1 pivot
# 1 pixar
# 1 pizazz
# 23 place
# 1 placement
# 8 plain
# 3 plan
# 3 planet
# 1 plant
# 2 plate
# 1 platitud
# 1 platter
# 1 plausibl
# 52 play
# 1 playbook
# 1 played
# 6 player
# 1 playoff
# 1 playth
# 2 playwright
# 10 pleas
# 6 pleasant
# 3 pleasantli
# 2 pleaser
# 1 pleasingli
# 11 pleasur
# 12 plenti
# 1 plethora
# 1 plex
# 1 pli
# 2 plight
# 8 plod
# 52 plot
# 1 ploy
# 2 plu
# 1 pluck
# 2 plucki
# 1 plummer
# 1 plummet
# 1 plump
# 1 plunder
# 2 plung
# 1 pluto
# 1 plympton
# 1 poca
# 3 poem
# 3 poet
# 4 poetic
# 5 poetri
# 1 poignanc
# 7 poignant
# 42 point
# 3 pointless
# 5 poke
# 1 pokemon
# 1 pokepi
# 3 polanski
# 1 police
# 2 polici
# 1 policial
# 3 polish
# 26 polit
# 1 pomo
# 3 pompou
# 3 ponder
# 1 poof
# 4 pool
# 7 poor
# 5 poorli
# 5 pop
# 4 popcorn
# 1 popul
# 1 populac
# 3 popular
# 2 por
# 1 porcelain
# 2 pore
# 1 porn
# 1 porno
# 1 portent
# 12 portrait
# 11 portray
# 4 pose
# 1 posibl
# 13 posit
# 2 possess
# 24 possibl
# 1 possui
# 8 post
# 3 postcard
# 2 postmodern
# 2 postur
# 2 pot
# 1 potenc
# 1 potent
# 10 potenti
# 1 potshot
# 2 potter
# 1 pound
# 1 pouty
# 1 poverti
# 7 pow
# 40 power
# 1 powerpuff
# 3 practic
# 6 prais
# 1 praiseworthi
# 1 prank
# 1 prankster
# 4 pratfal
# 1 prattl
# 3 pray
# 3 pre
# 3 preach
# 1 preachi
# 1 preachy
# 1 preced
# 5 preciou
# 1 precious
# 5 precis
# 1 precisa
# 8 predecessor
# 29 predict
# 2 predispos
# 1 predominantli
# 1 prefeminist
# 3 prefer
# 1 pregnant
# 1 prehistor
# 1 prejudic
# 1 prelud
# 19 premis
# 1 premisa
# 1 preoccup
# 1 preordain
# 1 prepackag
# 1 prepar
# 4 preposter
# 1 prescrib
# 6 presenc
# 18 present
# 1 preserv
# 6 press
# 2 pressur
# 1 presum
# 1 preteen
# 6 pretend
# 4 pretens
# 12 pretenti
# 19 pretti
# 1 prevail
# 4 prevent
# 1 preview
# 4 previou
# 1 prewarn
# 6 price
# 2 priceless
# 2 pride
# 1 primal
# 4 primarili
# 1 primavera
# 3 prime
# 1 primer
# 1 primit
# 1 princip
# 1 principl
# 2 print
# 1 prism
# 6 prison
# 1 prissi
# 2 pristin
# 4 privat
# 2 privileg
# 1 prize
# 3 pro
# 15 probabl
# 5 probe
# 22 problem
# 1 problemat
# 1 proce
# 1 procedur
# 4 proceed
# 6 process
# 10 produc
# 25 product
# 2 profan
# 6 profession
# 1 professor
# 1 profici
# 6 profil
# 5 profound
# 1 profoundli
# 1 profund
# 2 program
# 4 progress
# 15 project
# 2 promin
# 13 promis
# 4 promot
# 1 prompt
# 1 pron
# 1 pronounc
# 2 proof
# 1 prop
# 5 propaganda
# 2 proper
# 1 properli
# 1 properti
# 1 propheci
# 1 proport
# 1 prose
# 5 prospect
# 2 prostitut
# 5 protagonist
# 1 protestor
# 1 protract
# 3 proud
# 22 prove
# 17 provid
# 1 provinc
# 10 provoc
# 11 provok
# 1 prowess
# 1 prozac
# 3 prurient
# 3 pryor
# 1 pseudo
# 2 psych
# 1 psychedel
# 1 psychic
# 16 psycholog
# 1 psychopathi
# 1 psychot
# 1 pta
# 6 public
# 2 publicist
# 1 puccini
# 1 pudo
# 2 pue
# 1 pul
# 1 pulchritud
# 15 pull
# 2 pulp
# 1 pulpi
# 2 puls
# 1 pulsat
# 4 pumpkin
# 1 pun
# 12 punch
# 1 punctuat
# 2 pungent
# 3 punish
# 1 punit
# 1 punk
# 1 punni
# 1 puppet
# 1 purdi
# 11 pure
# 1 purport
# 2 purportedli
# 9 purpos
# 2 purposeless
# 1 pursu
# 6 push
# 28 put
# 1 putrid
# 5 puzzl
# 2 pyrotechn
# 1 python
# 1 quaint
# 2 qualifi
# 10 qualiti
# 1 quando
# 4 quarter
# 2 que
# 5 queen
# 1 quell
# 1 quentin
# 3 quest
# 16 question
# 1 quibbl
# 2 quick
# 2 quicki
# 7 quickli
# 10 quiet
# 7 quietli
# 1 quinn
# 1 quintessenti
# 2 quirk
# 14 quirki
# 31 quit
# 1 quite
# 1 quixot
# 1 qut
# 1 rabbit
# 1 raccoon
# 8 race
# 1 rachel
# 1 raci
# 5 racial
# 1 radcliff
# 2 radiant
# 3 radic
# 1 radioact
# 1 rae
# 1 rag
# 1 ragbag
# 1 rage
# 1 rah
# 1 rail
# 2 rainbow
# 1 raindrop
# 5 rais
# 1 raison
# 1 rak
# 2 ralli
# 2 ralph
# 3 ram
# 1 rama
# 6 rambl
# 1 rampantli
# 1 rampl
# 4 ramsay
# 2 randal
# 2 random
# 2 rang
# 5 rank
# 1 ransack
# 5 rap
# 2 rapidli
# 1 rapper
# 1 rapport
# 1 rapt
# 26 rare
# 1 rarest
# 4 rat
# 1 ratcatch
# 8 rate
# 32 rather
# 1 rational
# 1 ratliff
# 3 rattl
# 2 raunch
# 2 ravag
# 1 rave
# 1 ravel
# 1 ravish
# 6 raw
# 1 ray
# 1 raymond
# 1 razzle
# 40 re
# 7 reach
# 5 reaction
# 15 read
# 3 reaffirm
# 1 reagan
# 33 real
# 4 realism
# 9 realist
# 17 realiti
# 11 realiz
# 54 realli
# 20 reason
# 5 reassur
# 1 rebecca
# 1 rebellion
# 1 recal
# 1 recast
# 14 recent
# 1 recept
# 1 recess
# 1 recharg
# 2 recip
# 3 reckless
# 3 recogn
# 2 recogniz
# 8 recommend
# 1 recompens
# 1 reconceptu
# 1 reconcil
# 1 reconfigur
# 1 reconstruct
# 6 record
# 2 recov
# 1 recoveri
# 4 recycl
# 6 red
# 3 redeem
# 2 redempt
# 1 redgrav
# 1 redneck
# 1 redon
# 2 reduc
# 2 reduct
# 2 redund
# 1 reedi
# 1 reef
# 3 reek
# 1 rees
# 5 refer
# 1 referenc
# 1 referenti
# 7 reflect
# 1 reflex
# 5 refresh
# 4 refreshingli
# 2 refuge
# 1 refus
# 1 regal
# 7 regard
# 3 regardless
# 1 regener
# 4 reggio
# 2 reginald
# 1 region
# 1 regist
# 3 regret
# 1 regular
# 2 rehash
# 2 rehears
# 1 reheat
# 3 reign
# 1 reilli
# 1 rein
# 2 reinforc
# 4 reject
# 1 rejigg
# 3 rel
# 16 relationship
# 1 relax
# 2 relay
# 10 releas
# 4 relentless
# 4 relentlessli
# 4 relev
# 7 reli
# 3 reliabl
# 1 relianc
# 1 relic
# 2 relief
# 1 reliev
# 1 religi
# 1 reloc
# 1 reluct
# 15 remain
# 1 remaind
# 9 remak
# 11 remark
# 11 rememb
# 1 remembr
# 14 remind
# 4 remot
# 7 render
# 1 renegade
# 2 renner
# 4 reno
# 6 rent
# 1 rental
# 1 rep
# 1 repackag
# 1 repair
# 1 reparto
# 1 repeat
# 1 repeatedli
# 1 repellantli
# 6 repetit
# 1 repetiti
# 2 replac
# 2 replet
# 5 report
# 11 repres
# 1 represent
# 1 repress
# 1 reproduc
# 1 repugn
# 1 repuls
# 6 requir
# 1 requisit
# 1 rescu
# 1 research
# 6 resembl
# 1 resent
# 1 resid
# 1 residu
# 3 resist
# 3 resolut
# 6 reson
# 5 resort
# 1 resoundingli
# 12 respect
# 1 respond
# 3 respons
# 9 rest
# 1 restor
# 1 restraint
# 8 result
# 1 resultado
# 1 retain
# 2 retali
# 1 retel
# 1 rethink
# 1 retir
# 1 retool
# 5 retread
# 1 retreat
# 2 retro
# 1 retrograd
# 2 retrospect
# 10 return
# 4 reunion
# 15 reveal
# 1 revel
# 5 revelatori
# 2 reveng
# 3 rever
# 1 reverber
# 1 reveri
# 1 revers
# 1 revis
# 1 revolt
# 3 revolut
# 2 revolutionari
# 8 reward
# 1 rework
# 1 rey
# 1 rez
# 2 rhapsod
# 2 rhetor
# 1 rhino
# 6 rhythm
# 1 ribbon
# 2 rice
# 15 rich
# 2 richard
# 3 richer
# 2 richli
# 2 ridden
# 11 ride
# 2 rider
# 7 ridicul
# 1 rife
# 1 riff
# 1 rifkin
# 27 right
# 1 rigid
# 1 rigidli
# 3 rigor
# 7 ring
# 3 rip
# 3 ripe
# 1 ripoff
# 1 ripp
# 9 rise
# 1 risk
# 2 riski
# 2 ritchi
# 1 rite
# 1 rival
# 1 river
# 8 rivet
# 10 road
# 1 roadsid
# 3 roar
# 2 rob
# 6 robert
# 2 roberto
# 2 robin
# 1 robust
# 8 rock
# 1 rocki
# 1 rockwel
# 1 rodrigu
# 3 rodriguez
# 3 roger
# 4 rohmer
# 1 rohypnol
# 1 roil
# 1 rol
# 1 roland
# 15 role
# 5 roll
# 2 roller
# 1 rollerbal
# 1 rollick
# 3 roman
# 16 romanc
# 1 romanek
# 32 romant
# 2 romantic
# 1 romero
# 1 romijn
# 2 romp
# 1 ron
# 5 room
# 10 root
# 1 rope
# 1 rosario
# 3 rose
# 1 ross
# 3 rote
# 1 rotten
# 1 roug
# 2 rough
# 2 roughli
# 2 roughshod
# 2 rous
# 1 roussillon
# 1 rout
# 5 routin
# 1 rover
# 2 rowdi
# 1 rowl
# 1 royal
# 1 rubbo
# 1 rubenesqu
# 1 rubin
# 4 rude
# 1 rueful
# 1 ruffl
# 2 rug
# 1 rugrat
# 3 ruin
# 4 rule
# 1 rumbl
# 2 rumor
# 27 run
# 1 runner
# 1 runyon
# 1 rural
# 3 rush
# 4 russel
# 2 russian
# 1 russo
# 1 ruthless
# 1 ruthlessli
# 4 ryan
# 1 ryanovich
# 1 ryder
# 1 rymer
# 2 sabotag
# 4 saccharin
# 1 sacr
# 1 sacrif
# 4 sacrific
# 12 sad
# 2 saddest
# 1 saddl
# 1 sade
# 2 sadism
# 2 sadist
# 6 sadli
# 1 saeko
# 6 safe
# 1 sag
# 1 saga
# 4 said
# 1 sailboat
# 1 sailor
# 3 sake
# 2 salaci
# 1 sale
# 1 salient
# 2 salt
# 3 salton
# 2 salut
# 1 salvag
# 1 salvat
# 1 salvo
# 4 sam
# 1 same
# 1 samira
# 1 sampl
# 1 samuel
# 1 sanctifi
# 2 sanctimoni
# 3 sand
# 1 sandal
# 1 sander
# 2 sandler
# 1 sandlerian
# 2 sandra
# 2 sane
# 1 sanitis
# 4 santa
# 1 sap
# 4 sappi
# 6 sara
# 1 sarah
# 2 sarandon
# 1 sarcasm
# 1 sardin
# 2 sardon
# 1 sassi
# 1 satan
# 1 satin
# 13 satir
# 1 satisfact
# 1 satisfactorili
# 10 satisfi
# 1 satisfyingli
# 2 satur
# 2 saturday
# 1 saucer
# 1 sav
# 1 savag
# 10 save
# 2 savour
# 3 savvi
# 1 savviest
# 3 saw
# 34 say
# 3 sayl
# 4 scale
# 1 scam
# 1 scandinavian
# 1 scant
# 1 scarc
# 5 scare
# 9 scari
# 1 scarier
# 2 scariest
# 1 scarili
# 1 scarlet
# 1 scary
# 2 scath
# 4 scatter
# 1 scattershot
# 1 scen
# 5 scenario
# 39 scene
# 3 sceneri
# 1 scenic
# 1 scent
# 3 schaeffer
# 2 schepisi
# 1 scherfig
# 1 schiffer
# 1 schindler
# 1 schlock
# 1 schlocki
# 2 schmaltzi
# 2 schmidt
# 1 schneider
# 15 school
# 2 schrader
# 1 schumach
# 1 schwarzenegg
# 9 sci
# 4 scienc
# 1 science
# 1 scientist
# 1 scoob
# 5 scoobi
# 3 scope
# 1 scorchingli
# 7 score
# 1 scorpion
# 3 scorses
# 1 scott
# 1 scottish
# 1 scrap
# 1 scrappi
# 5 scratch
# 6 scream
# 1 screed
# 29 screen
# 19 screenplay
# 9 screenwrit
# 1 screw
# 2 screwbal
# 1 screwi
# 1 screwup
# 30 script
# 1 scripter
# 1 scriptwrit
# 1 scroog
# 1 scrub
# 3 scruffi
# 1 scummi
# 1 scuttl
# 2 se
# 8 sea
# 1 seacoast
# 5 seagal
# 2 seam
# 1 seami
# 1 sean
# 2 sear
# 4 search
# 1 seasid
# 2 season
# 9 seat
# 18 second
# 7 secret
# 3 secretari
# 2 sect
# 1 section
# 1 seduc
# 2 seduct
# 62 see
# 1 seed
# 1 seedi
# 9 seek
# 71 seem
# 4 seemingli
# 30 seen
# 3 segment
# 1 seigner
# 5 seinfeld
# 2 sel
# 2 seldahl
# 1 seldom
# 2 select
# 39 self
# 1 selfless
# 3 sell
# 2 semi
# 2 send
# 1 senegales
# 1 senior
# 42 sens
# 3 sensat
# 1 sensation
# 5 sensibl
# 12 sensit
# 3 sensual
# 2 sent
# 1 sentenc
# 20 sentiment
# 2 separ
# 1 sept
# 1 septemb
# 14 sequel
# 15 sequenc
# 1 sequin
# 2 serb
# 1 serbian
# 1 seren
# 16 seri
# 3 serial
# 12 seriou
# 12 serious
# 1 serrault
# 1 serri
# 17 serv
# 5 servic
# 1 session
# 32 set
# 1 seth
# 4 settl
# 1 settler
# 4 setup
# 1 seu
# 2 seven
# 1 seventy
# 10 sever
# 7 sex
# 5 sexi
# 9 sexual
# 1 shackl
# 1 shade
# 5 shadow
# 2 shadowi
# 1 shafer
# 1 shag
# 3 shaggi
# 1 shagster
# 2 shainberg
# 4 shake
# 1 shaken
# 2 shakespear
# 1 shakesperean
# 1 shaki
# 1 shall
# 6 shallow
# 1 sham
# 8 shame
# 1 shamelessli
# 1 shanghai
# 1 shap
# 1 shapabl
# 6 shape
# 1 shapeless
# 12 share
# 1 shark
# 6 sharp
# 1 sharpen
# 1 sharpi
# 1 shatner
# 1 shatter
# 1 shave
# 1 she
# 2 shed
# 1 sheep
# 5 sheer
# 2 sheet
# 1 shekhar
# 2 shelf
# 1 shenanigan
# 1 shepard
# 2 shift
# 2 shimmer
# 4 shine
# 2 shiner
# 1 shini
# 1 shinya
# 4 ship
# 1 shirley
# 1 shiver
# 1 shmear
# 13 shock
# 2 shocker
# 1 shockingli
# 1 shoddi
# 1 shoe
# 1 shook
# 10 shoot
# 1 shop
# 2 shore
# 20 short
# 2 shortcom
# 1 shorter
# 19 shot
# 4 shoulder
# 1 shout
# 1 shove
# 49 show
# 4 showcas
# 2 showdown
# 1 shower
# 2 showgirl
# 1 showi
# 1 shown
# 6 showtim
# 1 shred
# 1 shrek
# 1 shrieki
# 1 shrill
# 1 shrug
# 3 shut
# 2 shyamalan
# 1 siberian
# 3 sick
# 1 sickeningli
# 1 sickli
# 10 side
# 1 sided
# 1 sidey
# 1 sieg
# 1 siegel
# 1 siempr
# 1 siev
# 4 sight
# 6 sign
# 1 signal
# 4 signific
# 1 significantli
# 2 signpost
# 2 silberl
# 1 silberstein
# 1 silenc
# 2 silent
# 18 silli
# 1 silly
# 1 silver
# 4 similar
# 3 simon
# 14 simpl
# 1 simple
# 1 simplest
# 21 simpli
# 5 simplic
# 6 simplist
# 1 simul
# 4 simultan
# 1 sin
# 26 sinc
# 4 sincer
# 4 sing
# 13 singl
# 1 single
# 1 singular
# 1 sinist
# 2 sink
# 1 sinner
# 1 siren
# 1 sirk
# 4 sister
# 2 sisterhood
# 19 sit
# 1 sitcom
# 1 sitcomishli
# 14 situat
# 2 six
# 1 sixth
# 1 sixties
# 1 siz
# 1 size
# 2 sizzl
# 1 skate
# 2 skateboard
# 1 skeleton
# 1 skeptic
# 3 sketch
# 2 sketchi
# 1 skew
# 1 skewer
# 1 skil
# 8 skill
# 1 skim
# 1 skimpi
# 7 skin
# 2 skip
# 1 skit
# 1 skullduggeri
# 1 skunk
# 1 sky
# 1 sl2
# 1 slack
# 1 slacker
# 1 slain
# 1 slam
# 1 slant
# 4 slap
# 1 slapdash
# 6 slapstick
# 1 slash
# 5 slasher
# 1 slc
# 1 sleaz
# 2 sledgehamm
# 1 sleek
# 4 sleep
# 1 slender
# 4 sli
# 4 slice
# 7 slick
# 1 slickli
# 3 slide
# 3 slight
# 5 slightli
# 2 slim
# 1 slime
# 4 slip
# 2 slipperi
# 1 slipshod
# 1 sliver
# 2 slo
# 1 slob
# 1 slog
# 1 slogan
# 1 slope
# 4 sloppi
# 1 slovenli
# 14 slow
# 1 slowest
# 3 slowli
# 1 slum
# 1 slummi
# 1 slump
# 1 slur
# 11 small
# 2 smaller
# 1 smallest
# 21 smart
# 5 smarter
# 2 smartest
# 4 smartli
# 1 smelli
# 1 smil
# 10 smile
# 3 smith
# 1 smitten
# 2 smoke
# 1 smoki
# 2 smoochi
# 2 smooth
# 1 smoother
# 1 smoothli
# 1 smorgasbord
# 1 smother
# 2 smug
# 1 smugli
# 1 snack
# 1 snail
# 3 snap
# 2 snappi
# 2 snapshot
# 1 sneaki
# 1 sneer
# 1 sneez
# 1 snicker
# 3 snipe
# 1 snoot
# 3 snow
# 1 snowman
# 1 snuggl
# 6 so
# 10 soap
# 2 soapi
# 1 soar
# 4 sober
# 1 soccer
# 15 social
# 1 societ
# 9 societi
# 1 socio
# 2 sociolog
# 2 sociopath
# 1 soda
# 4 soderbergh
# 1 sofia
# 6 soft
# 1 soften
# 1 softest
# 2 soggi
# 1 solac
# 3 solari
# 4 soldier
# 2 sole
# 3 solemn
# 15 solid
# 1 solidli
# 1 soliloqui
# 1 solips
# 4 solondz
# 1 solondzian
# 2 somber
# 1 somebodi
# 1 someday
# 4 somehow
# 9 someon
# 1 someplac
# 46 someth
# 1 something
# 14 sometim
# 6 somewhat
# 3 somewher
# 1 sommer
# 1 somnambul
# 1 somnol
# 1 son
# 10 song
# 1 sonni
# 6 soon
# 1 sooth
# 2 sophi
# 9 sophist
# 1 sophomor
# 1 soprano
# 2 sordid
# 1 sore
# 1 sorimachi
# 3 sorri
# 3 sorrow
# 20 sort
# 9 soul
# 2 soulless
# 12 sound
# 6 soundtrack
# 1 soup
# 2 sour
# 1 sourc
# 5 south
# 1 southern
# 1 spac
# 3 space
# 1 spaceship
# 1 spacey
# 3 span
# 1 spangl
# 1 spanish
# 1 spar
# 5 spare
# 4 spark
# 1 sparkl
# 1 spasm
# 5 speak
# 2 spear
# 32 special
# 1 specialti
# 3 specif
# 1 specimen
# 1 speck
# 9 spectacl
# 5 spectacular
# 1 spectacularli
# 3 spectat
# 1 spectrum
# 2 specul
# 1 speech
# 1 speed
# 1 speedi
# 3 spell
# 1 spencer
# 7 spend
# 4 spent
# 11 spi
# 5 spice
# 1 spici
# 6 spielberg
# 1 spike
# 2 spin
# 1 spindli
# 1 spine
# 1 spinotti
# 16 spirit
# 2 spiritu
# 3 spit
# 3 spite
# 1 spittingli
# 1 splash
# 1 splat
# 3 splendid
# 3 splendidli
# 1 splendour
# 3 split
# 1 splittingli
# 1 spontan
# 2 spoof
# 1 spook
# 3 spooki
# 6 sport
# 6 spot
# 1 spotlight
# 2 spread
# 1 sprecher
# 1 sprightli
# 3 spring
# 1 springboard
# 2 spunk
# 2 spy
# 4 squander
# 4 squar
# 1 squeamish
# 3 squeez
# 1 squint
# 1 squirm
# 1 st
# 3 stab
# 1 stable
# 1 staci
# 2 stack
# 7 stage
# 1 stagecraft
# 2 stagey
# 1 stagger
# 1 staggeringli
# 1 stagi
# 1 staid
# 1 stain
# 1 staircas
# 6 stale
# 1 stalker
# 1 stamo
# 1 stamp
# 16 stand
# 10 standard
# 1 standbi
# 1 standout
# 1 standup
# 36 star
# 2 stardom
# 2 stare
# 1 starri
# 1 starship
# 18 start
# 1 starter
# 3 startl
# 2 stasi
# 4 state
# 1 statecraft
# 2 statement
# 1 statesmen
# 5 static
# 1 station
# 1 statu
# 1 statur
# 11 stay
# 1 steadfastli
# 8 steal
# 1 stealth
# 1 steam
# 1 steamboat
# 3 steep
# 2 steer
# 1 steinberg
# 5 step
# 1 stephen
# 5 stereotyp
# 2 steril
# 1 sterotyp
# 3 steve
# 7 steven
# 1 stevenon
# 3 stevenson
# 1 stew
# 8 stick
# 1 sticker
# 1 sticki
# 1 stiff
# 1 stifl
# 33 still
# 2 stillborn
# 1 stilt
# 5 stimul
# 1 stimulu
# 3 sting
# 2 stink
# 1 stinker
# 1 stinki
# 4 stir
# 1 stitch
# 3 stock
# 1 stockbrok
# 1 stodgi
# 1 stoical
# 2 stomach
# 1 stomp
# 5 stone
# 3 stoop
# 7 stop
# 1 stoppard
# 1 stor
# 2 store
# 137 stori
# 6 storylin
# 14 storytel
# 1 straddl
# 1 strafe
# 6 straight
# 2 straightforward
# 9 strain
# 2 strand
# 16 strang
# 1 stranger
# 1 strap
# 1 stray
# 1 stream
# 4 street
# 6 strength
# 1 stress
# 4 stretch
# 1 strewn
# 2 strictli
# 1 strident
# 12 strike
# 6 string
# 3 strip
# 1 stripped
# 1 strive
# 2 stroke
# 1 stroll
# 19 strong
# 1 stronger
# 1 strongest
# 1 struck
# 6 structur
# 6 struggl
# 1 strung
# 1 strut
# 2 stuart
# 1 stuck
# 1 stud
# 4 student
# 14 studi
# 6 studio
# 15 stuff
# 1 stultifyingli
# 1 stumbl
# 7 stun
# 1 stunningli
# 10 stunt
# 11 stupid
# 1 stupor
# 1 sturdi
# 1 stutter
# 7 styl
# 22 style
# 5 stylish
# 3 stylist
# 3 styliz
# 1 stymi
# 1 su
# 2 sub
# 3 subconsci
# 3 subcultur
# 27 subject
# 3 sublim
# 1 sublimin
# 1 submarin
# 1 submerg
# 1 subordin
# 2 subplot
# 10 substanc
# 1 substance
# 3 substitut
# 1 subtext
# 2 subtitl
# 8 subtl
# 1 subtler
# 1 subtlest
# 3 subtleti
# 3 subtli
# 1 suburban
# 1 suburbia
# 3 subvers
# 5 succe
# 7 succeed
# 18 success
# 2 successor
# 2 succumb
# 4 suck
# 3 sucker
# 2 sudden
# 1 suddenli
# 1 suert
# 1 suff
# 15 suffer
# 1 suffic
# 2 suffici
# 3 sugar
# 1 sugarco
# 2 sugari
# 1 sugarman
# 8 suggest
# 5 suit
# 1 suitabl
# 1 suitcas
# 1 sulk
# 1 sulki
# 2 sultri
# 2 sum
# 1 summ
# 12 summer
# 2 sun
# 2 sundanc
# 1 sunday
# 1 sung
# 1 sunk
# 1 sunni
# 1 sunnier
# 7 super
# 5 superb
# 3 superbl
# 1 supercharg
# 2 superfici
# 1 superflu
# 1 superhero
# 7 superior
# 1 supernatur
# 1 suppli
# 3 support
# 7 suppos
# 1 supposedli
# 1 suppress
# 17 sure
# 1 surefir
# 1 surehand
# 1 sureif
# 3 surf
# 4 surfac
# 1 surface
# 1 surfer
# 1 surgic
# 26 surpris
# 12 surprisingli
# 4 surreal
# 2 surrealist
# 2 surrend
# 3 surround
# 1 survey
# 5 surviv
# 2 susan
# 3 suspect
# 1 suspeito
# 4 suspend
# 18 suspens
# 1 suspici
# 11 sustain
# 1 sven
# 1 swagger
# 2 swallow
# 1 swamp
# 1 swan
# 1 swank
# 2 swashbuckl
# 1 sway
# 2 swear
# 1 swedish
# 5 sweep
# 18 sweet
# 2 sweetest
# 2 sweetheart
# 5 sweetli
# 2 swept
# 3 swim
# 2 swimfan
# 1 swimmer
# 3 swing
# 1 swipe
# 1 swoop
# 1 sydow
# 5 symbol
# 1 symmetr
# 3 sympathet
# 5 sympathi
# 2 symptom
# 2 synch
# 1 synchron
# 1 synthet
# 1 system
# 1 systemat
# 1 tabl
# 1 tabloid
# 1 taboo
# 3 tackl
# 1 tactic
# 1 tag
# 1 taint
# 1 taiwanes
# 1 tak
# 2 takashi
# 73 take
# 9 taken
# 1 takeoff
# 3 tal
# 1 talancn
# 41 tale
# 17 talent
# 1 talento
# 14 talk
# 3 talki
# 2 tall
# 1 tambin
# 1 tambm
# 1 tame
# 1 tamer
# 1 tan
# 1 tango
# 1 tanov
# 1 tantamount
# 6 tap
# 1 tape
# 3 tarantino
# 1 tarantula
# 9 target
# 1 tarkovski
# 2 tart
# 1 tartli
# 3 task
# 10 tast
# 2 tasteless
# 4 tasti
# 1 tat
# 3 tatter
# 2 tattoo
# 1 taught
# 1 taunt
# 3 taut
# 1 taverni
# 1 tax
# 2 taylor
# 1 tchaikovski
# 3 teach
# 7 teacher
# 2 team
# 10 tear
# 2 tearjerk
# 2 teas
# 1 techi
# 5 technic
# 1 techniqu
# 2 techno
# 3 technolog
# 14 tediou
# 1 tedium
# 1 teem
# 20 teen
# 7 teenag
# 3 teeth
# 2 telegraph
# 1 telemarket
# 1 telenovela
# 1 teleprompt
# 7 televis
# 25 tell
# 1 templ
# 3 tempt
# 2 temptat
# 2 ten
# 4 tend
# 2 tendenc
# 5 tender
# 1 tennesse
# 1 tens
# 7 tension
# 2 tenth
# 1 tepid
# 10 term
# 2 termin
# 1 terrain
# 2 terri
# 2 terribl
# 11 terrif
# 2 terrifi
# 2 territori
# 5 terror
# 1 terrorist
# 5 test
# 6 testament
# 2 testimoni
# 2 text
# 1 textbook
# 2 textur
# 5 than
# 12 thank
# 1 thanksgiv
# 1 that
# 29 the
# 20 theater
# 3 theatr
# 7 theatric
# 1 thekid
# 1 them
# 1 themat
# 13 theme
# 14 themselv
# 2 theori
# 2 theoriz
# 2 ther
# 1 therapi
# 1 therefor
# 1 theron
# 1 thesi
# 2 they
# 335 thi
# 5 thick
# 1 thieveri
# 10 thin
# 71 thing
# 36 think
# 2 thinli
# 1 thinly
# 1 thinner
# 3 third
# 2 thirst
# 3 thirteen
# 2 thirti
# 1 thirty
# 1 thoma
# 1 thorn
# 1 thorough
# 9 thoroughli
# 41 though
# 30 thought
# 5 thousand
# 1 thrash
# 1 threadbar
# 1 threat
# 2 threaten
# 21 three
# 1 threefold
# 3 thril
# 13 thrill
# 35 thriller
# 1 thrive
# 2 throat
# 8 throughout
# 9 throw
# 2 throwaway
# 1 thrown
# 3 thrust
# 1 thumb
# 1 thumpingli
# 2 tian
# 2 tick
# 4 ticket
# 1 tickl
# 1 tidal
# 2 tie
# 1 tiempo
# 1 tien
# 1 tiger
# 2 tight
# 1 tighten
# 2 tightli
# 2 tightrop
# 1 till
# 5 tim
# 122 time
# 1 timefram
# 1 timeless
# 1 timewast
# 2 tini
# 1 tiniest
# 1 tint
# 9 tire
# 5 tiresom
# 1 tiro
# 1 tissu
# 1 tit
# 1 titan
# 1 titil
# 28 titl
# 1 title
# 1 titular
# 4 to
# 1 toast
# 1 toback
# 4 today
# 3 todd
# 1 toddler
# 1 todo
# 3 toe
# 19 togeth
# 2 toilet
# 1 tok
# 11 told
# 1 toler
# 1 tolkien
# 1 tolstoy
# 5 tom
# 1 tomfooleri
# 3 tomorrow
# 1 tonal
# 12 tone
# 1 tonga
# 1 tongu
# 1 tongue
# 6 toni
# 1 tonight
# 4 too
# 6 took
# 3 tool
# 1 toothless
# 16 top
# 4 topic
# 1 topnotch
# 1 torment
# 1 torn
# 1 torpedo
# 1 torpor
# 3 tortur
# 1 tosca
# 3 toss
# 7 total
# 1 totalitarian
# 27 touch
# 7 tough
# 1 tougher
# 3 tour
# 1 tourist
# 5 toward
# 1 tower
# 1 town
# 2 toy
# 4 trace
# 1 traci
# 1 track
# 1 trad
# 1 trade
# 1 trademark
# 7 tradit
# 1 traffic
# 13 tragedi
# 5 tragic
# 1 trail
# 2 trailer
# 3 train
# 1 trainspot
# 1 trait
# 7 transcend
# 1 transcript
# 1 transfix
# 3 transform
# 1 transgress
# 1 transit
# 4 transpar
# 1 transplant
# 2 transport
# 5 trap
# 4 trash
# 2 trashi
# 1 trauma
# 4 travail
# 2 travel
# 1 treacl
# 3 tread
# 7 treasur
# 9 treat
# 5 treatment
# 1 tree
# 3 trek
# 1 trembl
# 2 tremend
# 1 tremor
# 1 trenchant
# 1 trend
# 1 trey
# 41 tri
# 2 trial
# 1 tribul
# 4 tribut
# 3 trick
# 1 tricki
# 1 tried
# 7 trifl
# 1 trilog
# 1 trim
# 1 trio
# 9 trip
# 1 tripl
# 1 triple
# 2 trite
# 8 triumph
# 1 triumphantli
# 2 trivial
# 1 trocadilho
# 1 troll
# 3 trooper
# 1 trope
# 1 trot
# 1 troubadour
# 8 troubl
# 1 trounc
# 1 trove
# 1 tru
# 13 true
# 2 truffl
# 16 truli
# 1 trumpet
# 2 trust
# 5 truth
# 1 tryingli
# 3 tsai
# 1 tsukamoto
# 1 tu
# 1 tub
# 1 tuba
# 1 tube
# 1 tuck
# 2 tucker
# 3 tug
# 1 tumult
# 1 tumultu
# 1 tun
# 1 tuna
# 4 tune
# 1 tuneless
# 1 tunisian
# 1 tunnel
# 2 tunney
# 1 turd
# 1 turgid
# 1 turk
# 1 turkey
# 1 turmoil
# 34 turn
# 3 turntabl
# 1 turturro
# 1 tuxedo
# 14 tv
# 1 twaddl
# 1 tweak
# 1 tweedi
# 1 twenty
# 1 twentysometh
# 3 twice
# 1 twin
# 1 twinki
# 1 twinkl
# 1 twirl
# 11 twist
# 1 twisti
# 51 two
# 6 type
# 6 typic
# 1 typifi
# 11 ugli
# 1 uh
# 1 uk
# 41 ultim
# 1 ultra
# 3 um
# 1 uma
# 1 un
# 2 una
# 1 unabash
# 3 unabashedli
# 3 unabl
# 1 unaccount
# 1 unamus
# 3 unapologet
# 2 unashamedli
# 2 unassum
# 1 unawar
# 1 unbalanc
# 2 unbear
# 2 unbeliev
# 1 unblink
# 1 unbridl
# 3 uncanni
# 1 uncertain
# 1 uncertainti
# 1 uncinemat
# 1 uncl
# 1 unclassifi
# 1 unclean
# 1 unclear
# 1 unclutt
# 5 uncomfort
# 2 uncommonli
# 1 uncompel
# 3 uncompromis
# 1 unconnect
# 1 uncontrol
# 1 unconvent
# 4 unconvinc
# 1 undead
# 1 undemand
# 2 undeni
# 2 under
# 1 underappreci
# 1 underbelli
# 1 undercov
# 2 undercurr
# 3 undercut
# 1 underdog
# 1 underdramat
# 1 underestim
# 4 underli
# 4 undermin
# 2 underneath
# 1 undernourish
# 4 underst
# 17 understand
# 2 underwear
# 1 undisput
# 1 undistinguish
# 1 undo
# 1 undogmat
# 3 undon
# 3 undoubtedli
# 1 undress
# 2 uneas
# 1 uneasi
# 1 uneasili
# 1 unembarrass
# 1 unemot
# 1 unencourag
# 1 unengag
# 1 unessenti
# 1 unev
# 6 uneven
# 6 unexpect
# 1 unexplain
# 1 unfairli
# 1 unfaith
# 1 unfamiliar
# 1 unfinish
# 4 unflinch
# 3 unfocus
# 7 unfold
# 4 unforc
# 1 unforgett
# 12 unfortun
# 3 unfulfil
# 4 unfunni
# 1 ungainli
# 1 unhappi
# 3 unhurri
# 1 uni
# 5 unimagin
# 1 unimpress
# 1 uninhibit
# 1 uniniti
# 2 uninspir
# 4 unintent
# 1 uninterest
# 2 uninvolv
# 9 uniqu
# 1 unit
# 6 univers
# 1 unknow
# 5 unless
# 8 unlik
# 2 unmemor
# 1 unmention
# 1 unmistak
# 1 unnam
# 3 unnecessari
# 1 unnerv
# 1 unnot
# 2 uno
# 1 unorigin
# 1 unorthodox
# 4 unpleas
# 1 unpleasantli
# 2 unpredict
# 2 unpretenti
# 1 unravel
# 1 unread
# 3 unreal
# 1 unrelentingli
# 1 unremark
# 1 unrepent
# 1 unrepentantli
# 1 unreward
# 1 unsaid
# 2 unsatisfi
# 1 unscath
# 1 unschool
# 4 unsentiment
# 8 unsettl
# 1 unsettlingli
# 1 unshap
# 1 unsophist
# 1 unspool
# 1 unsteadi
# 2 unsubtl
# 2 unsuccess
# 1 unsung
# 2 unsur
# 1 unsurpris
# 1 unsympathet
# 1 untold
# 1 untrain
# 1 unturn
# 7 unusu
# 1 unwav
# 2 unwieldi
# 1 unwilling
# 13 up
# 2 upbeat
# 3 updat
# 1 upholst
# 7 uplift
# 1 upload
# 8 upon
# 3 upper
# 2 upsid
# 8 urban
# 3 urg
# 5 urgenc
# 2 urgent
# 66 us
# 32 use
# 2 useless
# 19 usual
# 4 utter
# 7 utterli
# 1 uzumaki
# 4 vagu
# 2 valiantli
# 1 valid
# 12 valu
# 2 valuabl
# 4 vampir
# 2 van
# 1 vanish
# 1 vapid
# 1 vapor
# 1 variabl
# 1 variant
# 6 variat
# 1 varieti
# 1 variou
# 2 vast
# 33 ve
# 1 vece
# 3 veer
# 6 vehicl
# 2 veil
# 1 vein
# 1 veljohnson
# 1 velma
# 1 veloc
# 1 venal
# 2 veneer
# 2 venic
# 1 vent
# 2 ventur
# 1 ver
# 1 verac
# 2 verbal
# 1 verdaderament
# 1 verdict
# 1 verdu
# 1 veret
# 2 verg
# 68 veri
# 1 verisimilitud
# 1 verismo
# 1 veroniqu
# 1 vers
# 12 version
# 1 versu
# 1 vertic
# 1 vertigo
# 1 vessel
# 1 vez
# 2 via
# 1 vibe
# 2 vibrant
# 2 vicari
# 3 victim
# 2 victori
# 24 video
# 2 videodrom
# 1 vietnam
# 2 vietnames
# 20 view
# 22 viewer
# 2 viewpoint
# 1 vigil
# 2 vile
# 1 villain
# 3 villeneuv
# 1 vin
# 2 vincent
# 1 vinegar
# 1 vintag
# 1 violat
# 11 violenc
# 8 violent
# 2 virtu
# 6 virtual
# 3 virtuos
# 1 virtuoso
# 4 viscer
# 2 visibl
# 7 vision
# 2 vista
# 35 visual
# 4 vital
# 1 viveka
# 8 vivid
# 1 vividli
# 9 voic
# 1 void
# 2 volatil
# 1 voluptu
# 1 vomit
# 1 von
# 1 vote
# 1 vow
# 1 voyag
# 4 vs
# 2 vu
# 5 vulgar
# 3 vulner
# 66 wa
# 4 wacki
# 3 wade
# 1 wafer
# 1 wahlberg
# 1 wail
# 11 wait
# 3 wake
# 10 walk
# 4 wall
# 3 wallac
# 1 walled
# 4 wallet
# 1 walli
# 3 wallop
# 2 wallow
# 1 walsh
# 1 walt
# 2 walter
# 1 waltz
# 1 wan
# 1 wander
# 1 wane
# 2 wannab
# 1 wannabe
# 34 want
# 24 war
# 1 ward
# 1 warden
# 2 warfar
# 1 wari
# 1 warlord
# 8 warm
# 2 warmed
# 1 warmest
# 6 warmth
# 3 warn
# 1 warner
# 2 warp
# 2 warrior
# 1 wartim
# 1 wash
# 1 washi
# 4 washington
# 1 washout
# 10 wast
# 1 wat
# 59 watch
# 4 watchabl
# 9 water
# 1 waterboy
# 1 watt
# 1 wattag
# 4 wave
# 86 way
# 1 waydowntown
# 2 wayn
# 2 we
# 5 weak
# 1 weapon
# 1 weaponri
# 10 wear
# 2 weari
# 3 weav
# 3 weaver
# 1 web
# 1 weber
# 5 wed
# 1 wednesday
# 4 week
# 1 weekend
# 2 weep
# 2 weepi
# 2 weigh
# 6 weight
# 1 weighti
# 1 weinstein
# 11 weird
# 1 weirdli
# 1 weirdo
# 1 weiss
# 1 weissman
# 8 welcom
# 92 well
# 1 welsh
# 1 wen
# 1 wendigo
# 5 went
# 1 werewolf
# 1 wesley
# 2 west
# 1 westbrook
# 2 western
# 1 wet
# 1 wetsuit
# 1 whack
# 3 whale
# 3 what
# 5 whatev
# 1 whatsoev
# 1 wheel
# 1 wheezi
# 1 wherea
# 1 wherein
# 1 wherev
# 12 whether
# 21 whi
# 1 whiff
# 1 whiffle
# 1 whimsi
# 5 whimsic
# 1 whini
# 1 whippersnapp
# 1 whirl
# 1 whisper
# 2 whit
# 7 white
# 1 whitewash
# 1 who
# 2 whodunit
# 22 whole
# 1 wholesom
# 6 wholli
# 1 whoop
# 21 whose
# 1 wick
# 2 wickedli
# 5 wide
# 1 widen
# 1 widowmak
# 1 wield
# 2 wierzbicki
# 1 wif
# 4 wife
# 1 wig
# 1 wiggl
# 2 wilco
# 14 wild
# 1 wilder
# 1 wildest
# 8 wildli
# 1 wildlif
# 1 willam
# 4 willi
# 9 william
# 2 willing
# 1 wilson
# 1 wimmer
# 21 win
# 1 winc
# 1 wincingli
# 8 wind
# 1 windbag
# 4 window
# 4 windtalk
# 2 wink
# 2 winn
# 4 winner
# 1 wisdom
# 7 wise
# 1 wiseacr
# 1 wisecrack
# 2 wiseman
# 1 wiser
# 6 wish
# 1 wishy
# 1 wisp
# 1 wist
# 21 wit
# 2 witch
# 1 wither
# 2 witherspoon
# 3 within
# 53 without
# 1 withstand
# 1 witless
# 1 wittgenstein
# 9 witti
# 19 wo
# 2 wobbl
# 1 woefulli
# 1 wollter
# 1 wolodarski
# 11 woman
# 11 women
# 26 wonder
# 2 wondrous
# 1 wonton
# 6 woo
# 1 wood
# 2 wooden
# 5 woodi
# 1 woodman
# 1 wool
# 1 woozi
# 12 word
# 1 wordi
# 1 wordplay
# 105 work
# 1 workabl
# 1 workaday
# 2 workout
# 1 workshop
# 38 world
# 1 worldview
# 1 worm
# 2 worn
# 3 worri
# 8 wors
# 1 worship
# 13 worst
# 15 worth
# 11 worthi
# 1 worthless
# 6 worthwhil
# 60 would
# 3 wound
# 1 woven
# 4 wow
# 7 wrap
# 1 wreak
# 3 wreck
# 1 wreckag
# 6 wrench
# 5 wri
# 1 wrinkl
# 5 writ
# 10 write
# 18 writer
# 1 writh
# 11 written
# 6 wrong
# 3 wrote
# 1 wryli
# 2 wwii
# 1 xenophob
# 1 xma
# 3 xx
# 3 ya
# 1 yacht
# 1 yammer
# 1 yank
# 1 yard
# 8 yarn
# 3 yawn
# 12 ye
# 1 yeah
# 55 year
# 1 yearn
# 1 years
# 1 yellow
# 2 yesterday
# 33 yet
# 1 yiddish
# 2 yield
# 2 york
# 1 yorker
# 1 yosuk
# 1 you
# 19 young
# 4 younger
# 2 youngster
# 2 your
# 1 yourself
# 3 youth
# 2 yu
# 1 yuk
# 1 yuppi
# 1 ze
# 1 zeal
# 2 zealand
# 1 zeitgeist
# 1 zelda
# 1 zellweg
# 1 zemecki
# 3 zero
# 4 zhang
# 1 zhao
# 1 zhuangzhuang
# 1 zigzag
# 1 zing
# 1 zinger
# 3 zippi
# 1 zoe
# 1 zombi
# 2 zone
# 1 zucker

# %%
from sklearn.linear_model import LogisticRegression
def do_LOGIT(x,y,xv,yv):
    model = LogisticRegression()
    model = model.fit(x, y)
    print("Accuracy under training: ",model.score(x,y))
    print("Accuracy under validation: ",model.score(xv,yv))
    return model
log_model = do_LOGIT(features_train,labels_train,features_val,labels_val)
# Out:
# ('Accuracy under training: ', 0.9834797891036907)
# ('Accuracy under validation: ', 0.7249647390691114)

# %% [markdown]
# <a id="segundo"></a>
# ## 2. Job Salary Prediction
#
# En esta sección se trabajará con el problema de predecir el salario que ofrece un anuncio en internet a través unicamente del texto del anuncio. El dataset es ofrecido por *Adzuna* como una competencia en la plataforma más grande de *data science* Kaggle, a través del siguiente __[link](https://www.kaggle.com/c/job-salary-prediction)__ el cual el obetivo es tener un motor que pueda predecir el salario de cualquier anuncio de trabajo en Reunio Unido, para poder mejorar la experiencia de los usuarios que buscar trabajos.
#
# <img src="http://s5047.pcdn.co/wp-content/uploads/2013/05/salary-prediction-engine-v2.png" title="Title text" width="50%"/>
#
# La métrica de evaluación de la competencia es MAE (*mean absolute error*):
#
# $$
# L = \frac{1}{N} \sum_i^N  \mid y - \hat{y} \mid
# $$
#
#
# Para descargar los datos a utilizar (*Train_rev1*) debe estar registrado en la plataforma de Kaggle. Se cuenta con cientos de miles registros con textos sin procesar, es decir, no están estructurados.
#
#
# > a) Carge los datos *csv* de entrenamiento y cree un conjunto de validación con los últimos 10 mil datos en un dataframe de *pandas*. Describa los datos, apóyese de gráficos ¿Cuántos datos hay en cada conjunto?
# ```python
# import pandas as pd
# df = pd.read_csv("Train_rev1.csv")
# df_train = df.iloc[:-10000]
# df_val = df.iloc[-10000:]
# ...#load other sets
# df.head()
# ```
# *Recuerde que si no puede trabajar con todos los datos, debido a su volumen, puede muestrear*
#
#
# > b) Extraiga los datos de cada conjunto con los que trabajará, $X$, los textos, e $y$, los salarios.
# ```python
# text = df.FullDescription
# salary = df.SalaryNormalized
# ```
#
# > c) Realice un pre-procesamiento a los datos brutos de texto para extraer características y generar la representación de los datos de entrada al modelo $\vec{x}$. Comente sobre lo realizado.
#
# > d) Intente resolver el problema enfrentándolo como regresión con el modelo de regresión lineal ordinaria en *sklearn*. ¿Qué es lo que hace *fit_intercept=True*? Evalúe la función objetivo utilizada y la métrica de la competencia (*mean absolute error*) en ambos conjuntos generados en el punto a). Comente lo observado.
# ```python
# from sklearn.linear_model import LinearRegression as LR
# model = LR(fit_intercept=True, normalize=False)
# model.fit(X_train,y_train)
# ... #measure F.O.
# from sklearn.metrics import mean_absolute_error #measure MAE
# print("MAE on train: ",mean_absolute_error(y_train, model.predict(X_train)))
# print("MAE on validation: ",mean_absolute_error(y_val, model.predict(X_val)))
# ```
#
# > e) Mejore sus resultados en base a la métrica de la competencia (MAE) sobre el conjunto de validación. Comente sobre lo realizado.
# *No se le pide que imite los resultados ganadores de la competencia (MAE de 3400), sino que mejore lo alcanzado siendo creativo*
# <div class="alert alert-warning"> HINT: Una opción es cambiar el *approach* de resolución desde regresión a clasificación</div>

# %%
import pandas as pd
df = pd.read_csv("./Test_rev1.csv")
df.head()
# Out:
#          Id                               Title  \
# 0  11888454        Business Development Manager
# 1  11988350            Internal Account Manager
# 2  12612558        Engineering Systems Analysts
# 3  12613014  CIS Systems Engineering Consultant
# 4  22454872       CNC Miller / Programmer Fanac
#
#                                      FullDescription  \
# 0  The Company: Our client is a national training...
# 1  The Company: Founded in **** our client is a U...
# 2  Engineering Systems Analysts Surrey ****K Loca...
# 3  CIS Systems Engineering Consultant Bristol  So...
# 4  CNC Miller / Programmer Fanac Fleet, Hampshire...
#
#                        LocationRaw   LocationNormalized ContractType  \
# 0            Tyne Wear, North East  Newcastle Upon Tyne          NaN
# 1        Tyne and Wear, North East  Newcastle Upon Tyne          NaN
# 2   Surrey, South East, South East               Surrey          NaN
# 3  Bristol, South West, South West              Bristol          NaN
# 4                 Fleet, Hampshire                Fleet          NaN
#
#   ContractTime                       Company            Category  \
# 0    permanent            Asset Appointments       Teaching Jobs
# 1    permanent            Asset Appointments    Consultancy Jobs
# 2    permanent  Gregory Martin International    Engineering Jobs
# 3    permanent  Gregory Martin International    Engineering Jobs
# 4    permanent  Gregory Martin International  Manufacturing Jobs
#
#          SourceName
# 0  cv-library.co.uk
# 1  cv-library.co.uk
# 2  cv-library.co.uk
# 3  cv-library.co.uk
# 4  cv-library.co.uk

# %%
df.shape
# Out:
# (122463, 10)

# %%
df.iloc[-10000:].shape
# Out:
# (10000, 10)

# %%
df.FullDescription.loc[0]
# Out:
# 'Engineering Systems Analyst Dorking Surrey Salary ****K Our client is located in Dorking, Surrey and are looking for Engineering Systems Analyst our client provides specialist software development Keywords Mathematical Modelling, Risk Analysis, System Modelling, Optimisation, MISER, PIONEEER Engineering Systems Analyst Dorking Surrey Salary ****K'

# %% [markdown]
# <a id="tercero"></a>
# ## 3. Linear Regression by hand
#
# En esta sección se le pedirá que implemente la regresión lineal a través del algoritmo SGD (*Stochastic Gradient Descend*) para encontrar los parámetros de la regresión a través de este algoritmo de manera iterativa. La técnica de SGD es sin duda dominante al momento de entrenar modelos en máquinas de aprendizaje cuando la solución no tiene un óptimo derivable analíticamente, como la regresión lineal. Sin embargo se le pedirá que compare en este caso con fines pedagógicos.
#
# $$ \beta^{(t+1)} \leftarrow \beta^{(t)} - \eta \nabla_{\beta^{(t)}} Loss $$
#
# Para lo que sigue de la actividad sólo podrá utilizar *numpy* (para operaciones de algebra lineal).
#
# > a) Escriba una función que calcule la función de pérdida error cuadrático medio (MSE - *mean squared error*) para un dato o para un conjunto de datos.
#
# > b) Escriba una función que calcule los parámetros de una regresión lineal simple de manera analítica (es decir el mínimo global).
#
# <div class="alert alert-warning"> Hint: ésto debería ser la ecuación desglosada de la derivada igual a 0, la cual incluye $(X^TX)^{-1}$</div>
#
#
# > c) Ahora escriba un programa que permita entrenar una regresión lineal a través del algoritmo SGD mostrado en la ecuación inicial, es decir, que de manera iterativa, vaya tomando un dato a la vez, y actualizando el parámetro $\beta$ a través del gradiente descendiente de la función de pérdida de la regresión lineal ordinaria. *Escriba explícitamente la derivada (gradiente).*
#
# > d) Demuestre que sus programas funcionan en un problema de regresión simple. Para esto utilice el dataset **Boston Housing** , disponible a través de la librería __[*sklearn*](http://scikit-learn.org)__, el cual corresponde a el precio de diferentes casas en Boston además de distintas características relevantes respecto al lugar, como por ejemplo el crimen en la ciudad, el número de habitaciones, que tan vieja es, distancia a lugares relevantes, entre otros. Éstas características deben combinarse linealmente para estimar el precio de la casa.
# <div class="alert alert-block alert-info">Es una buena práctica el normalizar los datos antes de trabajar con el modelo</div>
#
# ```python
# from sklearn.datasets import load_boston
# X_train,y_train = load_boston(return_X_y=True)[source]
# scaler = StandardScaler().fit(X_train)
# X_train = scaler.transform(X_train)
# ```
# Para evaluar los resultados, construya un gráfico correspondiente a la función de pérdida utilizada en el entrenamiento versus número de iteraciones, utilizando sólo el conjunto de entrenamiento (el objetivo de esta sección es familiarizarse con el algoritmo). Además de reportar el tiempo de entrenamiento mediante el algoritmo implementado en b) y c).
#
# > e) Varié la tasa de aprendizaje $\eta \in [0,1]$ del algoritmo SGD del punto c), compare los resultados entre sí y con la solución óptima encontrada en b). Comente.

# %% [markdown]
# ### Referencias
# [1] Hastie, T.; Tibshirani, R., Friedman, J. (2009), *The Elements of Statistical Learning*, Second Edition.
# Springer New York Inc.
# [2] http://statweb.stanford.edu/tibs/ElemStatLearn/datasets/
# https://en.wikipedia.org/wiki/Stop words
# [3] https://en.wikipedia.org/wiki/Stemming
# [4] https://en.wikipedia.org/wiki/Lemmatisation
# [5] http://scikit-learn.org/stable/modules/classes.html#module-sklearn.feature extraction.text
# [6] http://www.nltk.org/
# [7] https://gluon.mxnet.io/chapter06_optimization/gd-sgd-scratch.html
# [8] https://towardsdatascience.com/linear-regression-simplified-ordinary-least-square-vs-gradient-descent-48145de2cf76
