# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import keras
# Out:
# Using TensorFlow backend.

# %%
from keras.datasets import cifar10

(X_train, y_train), (X_test, y_test) = cifar10.load_data()

X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train.shape
# Out:
# (50000, 32, 32, 3)

# %%
from keras.layers import Dense,Flatten
from keras.models import Sequential
def clasification_model(shape):    
    clas = Sequential()
    clas.add(Flatten(input_shape=shape))
    clas.add(Dense(10,activation='softmax'))
    return clas

# %% [markdown]
# ### VGG 16

# %%
from keras.applications import vgg16
from keras.layers import Input
#any input size image you want
#input_t = Input(shape = X_train.shape[1:])

model_VGG = vgg16.VGG16(include_top=True, weights='imagenet')
model_VGG.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# ...

# %%
#default input size? con que dimensiones de imagenes fue entrenado?

# %%
VGG16.layers[-2].activation
# Out:
# <function keras.activations.relu>

# %%
#preprocessing vgg
X_train_vgg =vgg16.preprocess_input(X_train)
# Out:
# (50000, 1, 1, 512)

# %%
model_VGG16 = clasification_model(X_train_vgg.shape[1:])
model_VGG16.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# flatten_1 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                5130
# ...
# Total params: 5,130
# Trainable params: 5,130
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Resnet

# %%
from keras.applications import resnet50
#from keras.layers import Input
#any input size image you want
#input_t = Input(shape = (224,224,3))

model_resnet = resnet50.ResNet50(include_top=True, weights='imagenet')
model_resnet.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_2 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 230, 230, 3)  0           input_2[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 112, 112, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 112, 112, 64) 256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 112, 112, 64) 0           bn_conv1[0][0]
# ...

# %%
#comparar flatten

# %%
X_train_resnet = resnet50.preprocess_input(X_train)

# %% [markdown]
# ### Inception

# %%
from keras.applications import inception_v3
#from keras.layers import Input
#any input size image you want
input_t = Input(shape =(299, 299, 3)) #default input dim

model_inception = inception_v3.InceptionV3(include_top=True, weights='imagenet',input_tensor=input_t)
model_inception.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_8 (InputLayer)            (None, 299, 299, 3)  0
# __________________________________________________________________________________________________
# conv2d_377 (Conv2D)             (None, 149, 149, 32) 864         input_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_377 (BatchN (None, 149, 149, 32) 96          conv2d_377[0][0]
# __________________________________________________________________________________________________
# activation_426 (Activation)     (None, 149, 149, 32) 0           batch_normalization_377[0][0]
# __________________________________________________________________________________________________
# conv2d_378 (Conv2D)             (None, 147, 147, 32) 9216        activation_426[0][0]
# ...

# %%
#preprocessing vgg
X_train_inception = inception_v3.preprocess_input(X_train_upsampler)

X_train_inception = Inception.predict(X_train_inception,batch_size=64)
X_train_inception.shape
# Out:
# (50000, 1, 1, 2048)

# %%
from keras.layers import Input
#any input size image you want
input_t = Input(shape =(n1,n2,3)) #3 channels

model = modelkeras(include_top=False, weights='imagenet',input_tensor=input_t)

# %%
#if size n1=n2=32? cifar

# %%
from keras.applications import densenet
#any input size image you want
#input_t = Input(shape = X_train.shape[1:])

model_densenet = densenet.DenseNet121(include_top=True, weights='imagenet')
model_densenet.summary()
# Out:
# ...
# 34127872/34115984 [==============================] - 13s 0us/step
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_9 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 230, 230, 3)  0           input_9[0][0]
# __________________________________________________________________________________________________
# conv1/conv (Conv2D)             (None, 112, 112, 64) 9408        zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# conv1/bn (BatchNormalization)   (None, 112, 112, 64) 256         conv1/conv[0][0]
# __________________________________________________________________________________________________
# ...

# %% [markdown]
# ## Try it

# %%
from keras.optimizers import SGD

model_Inception.compile(loss='sparse_categorical_crossentropy',optimizer=SGD(lr=0.01),metrics=["accuracy"])
model_Inception.fit(X_train_inception,y_train,epochs=10,batch_size=64)
# Out:
# Epoch 1/10
# 50000/50000 [==============================] - 7s 147us/step - loss: 1.2176 - acc: 0.5940
# Epoch 2/10
# 50000/50000 [==============================] - 4s 80us/step - loss: 0.9594 - acc: 0.6789
# Epoch 3/10
# 50000/50000 [==============================] - 4s 81us/step - loss: 0.9055 - acc: 0.6939
# Epoch 4/10
# 50000/50000 [==============================] - 4s 81us/step - loss: 0.8781 - acc: 0.7022
# Epoch 5/10
# 50000/50000 [==============================] - 4s 80us/step - loss: 0.8588 - acc: 0.7096
# Epoch 6/10
# 50000/50000 [==============================] - 4s 81us/step - loss: 0.8452 - acc: 0.7131
# Epoch 7/10
# 50000/50000 [==============================] - 4s 81us/step - loss: 0.8336 - acc: 0.7170
# Epoch 8/10
# 50000/50000 [==============================] - 4s 80us/step - loss: 0.8231 - acc: 0.7201
# Epoch 9/10
# 50000/50000 [==============================] - 4s 81us/step - loss: 0.8185 - acc: 0.7223
# Epoch 10/10
# ...

# %% [markdown]
# ## Evaluate

# %%
X_test_upsampler = upsampler.predict(X_test)

#preprocessing vgg
X_test_inception = inception_v3.preprocess_input(X_test_upsampler)
#predict features
X_test_inception = Inception.predict(X_test_inception,batch_size=64)
#evaluate
model_Inception.evaluate(X_test_inception,y_test)
# Out:
# 10000/10000 [==============================] - 3s 254us/step
# [1.0203402264595032, 0.6742]

# %%
model_Inception.evaluate(X_test_inception,y_test)
# Out:
# 10000/10000 [==============================] - 3s 256us/step
# [0.9228424575805664, 0.6969]
